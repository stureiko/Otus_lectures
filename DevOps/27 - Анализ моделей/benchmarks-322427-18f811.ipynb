# %% [markdown]
# # Пропускная способность инференса

# %%
# !pip install catboost -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 8.2 MB/s eta 0:00:00

# %%
from sklearn.datasets import load_digits

ds = load_digits()

X = ds["data"]
y = ds["target"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline

clf = Pipeline([
    # ("scaler", StandardScaler()),
    # ("classifier", LogisticRegression()),
    # ("classifier", RandomForestClassifier(n_estimators=100)),
    ("classifier", CatBoostClassifier(n_estimators=100)),
]).fit(X_train, y_train)
# Out:
# Learning rate set to 0.5
# 0:	learn: 1.5528448	total: 58.8ms	remaining: 5.82s
# 1:	learn: 1.0792717	total: 72.1ms	remaining: 3.53s
# 2:	learn: 0.7816384	total: 84ms	remaining: 2.71s
# 3:	learn: 0.6149772	total: 97.5ms	remaining: 2.34s
# 4:	learn: 0.5036011	total: 108ms	remaining: 2.06s
# 5:	learn: 0.4331487	total: 123ms	remaining: 1.92s
# 6:	learn: 0.3764895	total: 142ms	remaining: 1.89s
# 7:	learn: 0.3237940	total: 157ms	remaining: 1.81s
# 8:	learn: 0.2873393	total: 174ms	remaining: 1.75s
# 9:	learn: 0.2614587	total: 186ms	remaining: 1.68s
# 10:	learn: 0.2368273	total: 199ms	remaining: 1.61s
# 11:	learn: 0.2165800	total: 234ms	remaining: 1.72s
# 12:	learn: 0.1993735	total: 244ms	remaining: 1.63s
# 13:	learn: 0.1842734	total: 253ms	remaining: 1.55s
# 14:	learn: 0.1708763	total: 266ms	remaining: 1.51s
# 15:	learn: 0.1553851	total: 275ms	remaining: 1.45s
# 16:	learn: 0.1441707	total: 285ms	remaining: 1.39s
# 17:	learn: 0.1336074	total: 295ms	remaining: 1.34s
# 18:	learn: 0.1275729	total: 305ms	remaining: 1.3s
# 19:	learn: 0.1166224	total: 316ms	remaining: 1.26s
# 20:	learn: 0.1063135	total: 328ms	remaining: 1.24s
# 21:	learn: 0.1004044	total: 341ms	remaining: 1.21s
# 22:	learn: 0.0946065	total: 353ms	remaining: 1.18s
# 23:	learn: 0.0876238	total: 373ms	remaining: 1.18s
# 24:	learn: 0.0823517	total: 387ms	remaining: 1.16s
# 25:	learn: 0.0786830	total: 398ms	remaining: 1.13s
# 26:	learn: 0.0742317	total: 412ms	remaining: 1.11s
# 27:	learn: 0.0709700	total: 421ms	remaining: 1.08s
# 28:	learn: 0.0673844	total: 434ms	remaining: 1.06s
# 29:	learn: 0.0657374	total: 447ms	remaining: 1.04s
# 30:	learn: 0.0631856	total: 459ms	remaining: 1.02s
# 31:	learn: 0.0615613	total: 480ms	remaining: 1.02s
# 32:	learn: 0.0588253	total: 503ms	remaining: 1.02s
# 33:	learn: 0.0578148	total: 518ms	remaining: 1s
# 34:	learn: 0.0563250	total: 530ms	remaining: 985ms
# 35:	learn: 0.0551077	total: 541ms	remaining: 962ms
# 36:	learn: 0.0533642	total: 552ms	remaining: 939ms
# 37:	learn: 0.0522987	total: 560ms	remaining: 914ms
# 38:	learn: 0.0510607	total: 573ms	remaining: 896ms
# 39:	learn: 0.0496642	total: 581ms	remaining: 872ms
# 40:	learn: 0.0480824	total: 590ms	remaining: 849ms
# 41:	learn: 0.0467259	total: 599ms	remaining: 827ms
# 42:	learn: 0.0454183	total: 608ms	remaining: 806ms
# 43:	learn: 0.0435657	total: 616ms	remaining: 784ms
# 44:	learn: 0.0420702	total: 631ms	remaining: 771ms
# 45:	learn: 0.0411140	total: 644ms	remaining: 756ms
# 46:	learn: 0.0394875	total: 664ms	remaining: 749ms
# 47:	learn: 0.0381939	total: 676ms	remaining: 732ms
# 48:	learn: 0.0368238	total: 684ms	remaining: 711ms
# 49:	learn: 0.0353092	total: 699ms	remaining: 699ms
# 50:	learn: 0.0338856	total: 711ms	remaining: 683ms
# 51:	learn: 0.0331518	total: 731ms	remaining: 675ms
# 52:	learn: 0.0321479	total: 746ms	remaining: 662ms
# 53:	learn: 0.0311528	total: 757ms	remaining: 645ms
# 54:	learn: 0.0304546	total: 769ms	remaining: 629ms
# 55:	learn: 0.0296688	total: 780ms	remaining: 613ms
# 56:	learn: 0.0288652	total: 793ms	remaining: 598ms
# 57:	learn: 0.0283424	total: 806ms	remaining: 584ms
# 58:	learn: 0.0278722	total: 820ms	remaining: 570ms
# 59:	learn: 0.0274113	total: 841ms	remaining: 561ms
# 60:	learn: 0.0269516	total: 854ms	remaining: 546ms
# 61:	learn: 0.0261939	total: 867ms	remaining: 531ms
# 62:	learn: 0.0258041	total: 880ms	remaining: 517ms
# 63:	learn: 0.0253854	total: 892ms	remaining: 502ms
# 64:	learn: 0.0247565	total: 904ms	remaining: 487ms
# 65:	learn: 0.0240735	total: 930ms	remaining: 479ms
# 66:	learn: 0.0235083	total: 942ms	remaining: 464ms
# 67:	learn: 0.0231148	total: 953ms	remaining: 449ms
# 68:	learn: 0.0225053	total: 963ms	remaining: 433ms
# 69:	learn: 0.0220262	total: 975ms	remaining: 418ms
# 70:	learn: 0.0217289	total: 991ms	remaining: 405ms
# 71:	learn: 0.0215817	total: 1.01s	remaining: 392ms
# 72:	learn: 0.0210864	total: 1.02s	remaining: 377ms
# 73:	learn: 0.0206482	total: 1.03s	remaining: 361ms
# 74:	learn: 0.0202662	total: 1.04s	remaining: 346ms
# 75:	learn: 0.0201173	total: 1.06s	remaining: 335ms
# 76:	learn: 0.0199750	total: 1.08s	remaining: 324ms
# 77:	learn: 0.0197743	total: 1.09s	remaining: 309ms
# 78:	learn: 0.0193583	total: 1.11s	remaining: 294ms
# 79:	learn: 0.0190273	total: 1.12s	remaining: 281ms
# 80:	learn: 0.0187047	total: 1.13s	remaining: 266ms
# 81:	learn: 0.0183358	total: 1.15s	remaining: 252ms
# 82:	learn: 0.0179307	total: 1.16s	remaining: 237ms
# 83:	learn: 0.0177076	total: 1.17s	remaining: 222ms
# 84:	learn: 0.0175144	total: 1.17s	remaining: 207ms
# 85:	learn: 0.0172582	total: 1.18s	remaining: 192ms
# 86:	learn: 0.0170555	total: 1.19s	remaining: 178ms
# 87:	learn: 0.0167418	total: 1.21s	remaining: 164ms
# 88:	learn: 0.0165146	total: 1.22s	remaining: 150ms
# 89:	learn: 0.0162960	total: 1.22s	remaining: 136ms
# 90:	learn: 0.0160037	total: 1.23s	remaining: 122ms
# 91:	learn: 0.0158012	total: 1.25s	remaining: 108ms
# 92:	learn: 0.0155598	total: 1.26s	remaining: 94.7ms
# 93:	learn: 0.0153077	total: 1.27s	remaining: 80.9ms
# 94:	learn: 0.0150097	total: 1.28s	remaining: 67.2ms
# 95:	learn: 0.0148950	total: 1.29s	remaining: 53.7ms
# 96:	learn: 0.0147016	total: 1.3s	remaining: 40.4ms
# 97:	learn: 0.0144542	total: 1.32s	remaining: 26.9ms
# 98:	learn: 0.0143771	total: 1.33s	remaining: 13.4ms
# 99:	learn: 0.0141512	total: 1.34s	remaining: 0us

# %%
batch_sizes = [2**i for i in range(10)]

# %%
import numpy as np
from timeit import default_timer as timer

n_iterations = 100

elapsed = np.zeros((len(batch_sizes), n_iterations))

for i, bsize in enumerate(batch_sizes):
    for j in range(n_iterations):
        sample_idx = np.random.choice(a=X_test.shape[0], size=bsize)
        batch = X_test[sample_idx]
        start = timer()
        clf.predict(batch)
        end = timer()
        elapsed[i, j] = end - start

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.set()
elapsed_mean = elapsed.mean(axis=1)

throughput = batch_sizes / elapsed_mean

plt.plot(batch_sizes, throughput)
plt.title("Model throughput")
plt.xlabel("batch size")
plt.ylabel("predictions/s");

# %% [markdown]
# ## Transformers benchmark

# %%
# !pip install transformers==4.26.0 py3nvml -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 49.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00

# %%
from transformers import PyTorchBenchmark, PyTorchBenchmarkArguments

args = PyTorchBenchmarkArguments(models=["bert-base-uncased"], batch_sizes=[8], sequence_lengths=[8, 32, 128, 512])

benchmark = PyTorchBenchmark(args)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/benchmark/benchmark_args_utils.py:136: FutureWarning: The class <class 'transformers.benchmark.benchmark_args.PyTorchBenchmarkArguments'> is deprecated. Hugging Face Benchmarking utils are deprecated in general and it is advised to use external Benchmarking libraries  to benchmark Transformer models.
#   warnings.warn(
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/benchmark/benchmark_utils.py:615: FutureWarning: The class <class 'transformers.benchmark.benchmark.PyTorchBenchmark'> is deprecated. Hugging Face Benchmarking utils are deprecated in general and it is advised to use external Benchmarking libraries  to benchmark Transformer models.
#   warnings.warn(

# %%
results = benchmark.run()
# Out:
# 1 / 1
#
# ====================       INFERENCE - SPEED - RESULT       ====================
# --------------------------------------------------------------------------------
#           Model Name             Batch Size     Seq Length     Time in s
# --------------------------------------------------------------------------------
#       bert-base-uncased              8               8             0.016
#       bert-base-uncased              8               32            0.011
#       bert-base-uncased              8              128            0.021
#       bert-base-uncased              8              512             0.09
# --------------------------------------------------------------------------------
#
# ====================      INFERENCE - MEMORY - RESULT       ====================
# --------------------------------------------------------------------------------
#           Model Name             Batch Size     Seq Length    Memory in MB
# --------------------------------------------------------------------------------
#       bert-base-uncased              8               8              1699
#       bert-base-uncased              8               32             1731
#       bert-base-uncased              8              128             1867
#       bert-base-uncased              8              512             2449
# --------------------------------------------------------------------------------
