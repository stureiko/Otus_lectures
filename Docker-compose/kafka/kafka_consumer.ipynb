# %%
# %conda install kafka-python

# %%
from kafka import KafkaConsumer
from kafka.errors import NoBrokersAvailable, KafkaTimeoutError
from json import loads
import time

topic = "values_info"
bootstrap_servers = "127.0.0.1:9092"

while True:
    try:
        kafka_consumer = KafkaConsumer(
            topic,
            group_id ="2",
            bootstrap_servers=bootstrap_servers,
            value_deserializer=lambda x: loads(x.decode("utf-8")),
        )
        break
    except NoBrokersAvailable as e:
        print("No brokers available. Please check your Kafka server.")
        time.sleep(5)
    except KafkaTimeoutError as e:
        print("Kafka server is not responding. Please check your connection.")
        time.sleep(5)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        exit(1)
# Out:
# No brokers available. Please check your Kafka server.
# No brokers available. Please check your Kafka server.
# No brokers available. Please check your Kafka server.
# No brokers available. Please check your Kafka server.
# No brokers available. Please check your Kafka server.
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[6], line 11
#      10 try:
# ---> 11     kafka_consumer = KafkaConsumer(
#      12         topic,
#      13         group_id ="2",
#      14         bootstrap_servers=bootstrap_servers,
#      15         value_deserializer=lambda x: loads(x.decode("utf-8")),
#      16     )
#      17     break
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/consumer/group.py:387, in KafkaConsumer.__init__(self, *topics, **configs)
#     384     log.warning('use api_version=%s [tuple] -- "%s" as str is deprecated',
#     385                 str(self.config['api_version']), str_version)
# --> 387 self._client = self.config['kafka_client'](metrics=self._metrics, **self.config)
#     389 # Get auto-discovered / normalized version from client
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/client_async.py:262, in KafkaClient.__init__(self, **configs)
#     261 if self.config['api_version'] is None:
# --> 262     self.config['api_version'] = self.check_version()
#     263 elif self.config['api_version'] in BROKER_API_VERSIONS:
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/client_async.py:1074, in KafkaClient.check_version(self, node_id, timeout, **kwargs)
#    1073 else:
# -> 1074     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      18 except NoBrokersAvailable as e:
#      19     print("No brokers available. Please check your Kafka server.")
# ---> 20     time.sleep(5)
#      21 except KafkaTimeoutError as e:
#      22     print("Kafka server is not responding. Please check your connection.")
#
# KeyboardInterrupt:

# %%
for message in kafka_consumer:
    message = message.value
    print(message)
# Out:
# {'name': 'Glenn', 'surname': 'Lee', 'age': 81}
# {'name': 'Glenn', 'surname': 'Lee', 'age': 81}
# {'name': 'Glenn', 'surname': 'Lee', 'age': 81}
# {'name': 'Glenn', 'surname': 'Lee', 'age': 81}
# {'name': 'Glenn', 'surname': 'Lee', 'age': 81}
# {'name': 'Lisa', 'surname': 'Aguilar', 'age': 20}
# {'name': 'Cindy', 'surname': 'Smith', 'age': 80}
# {'name': 'James', 'surname': 'Roman', 'age': 30}
# {'name': 'Kevin', 'surname': 'Fox', 'age': 20}
# {'name': 'Elizabeth', 'surname': 'Rivera', 'age': 23}
# {'name': 'Rhonda', 'surname': 'Barnett', 'age': 43}
# {'name': 'Jesus', 'surname': 'Fletcher', 'age': 34}
# {'name': 'Gary', 'surname': 'Cox', 'age': 22}
# {'name': 'Debra', 'surname': 'Lewis', 'age': 50}
# {'name': 'Donald', 'surname': 'Haynes', 'age': 54}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for message in kafka_consumer:
#       2     message = message.value
#       3     print(message)
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/consumer/group.py:729, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     726 if not has_all_fetch_positions:
#     727     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 729 self._client.poll(timeout_ms=poll_timeout_ms)
#     730 # after the long poll, we should check whether the group needs to rebalance
#     731 # prior to returning data so that the group can stabilize faster
#     732 if self._coordinator.need_rejoin():
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/miniconda3/envs/otus/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /opt/miniconda3/envs/otus/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
