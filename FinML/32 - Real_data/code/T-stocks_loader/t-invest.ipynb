# %%
import os
from datetime import timedelta
import pandas as pd
from tinkoff.invest import Client, CandleInterval, InstrumentStatus
from tinkoff.invest.utils import now

# %%
t_sandbox_token = os.getenv("T_SANDBOX_TOKEN")

# %%
with Client(t_sandbox_token) as client:
    shares = client.instruments.shares(instrument_status=InstrumentStatus.INSTRUMENT_STATUS_BASE)
    shares_df = pd.DataFrame(shares.instruments)

    shares_df = shares_df[['figi', 'ticker', 'class_code','first_1min_candle_date', 'currency', 'name']]
    # будем загружать только те акции, которые торгуются в рублях
    shares_df = shares_df[shares_df['currency']=='rub'].reset_index(drop=True)

# %%
shares_df.head()
# Out:
#            figi ticker class_code    first_1min_candle_date currency  \
# 0  BBG004S68CV8   VSMO       TQBR 2018-03-07 19:56:00+00:00      rub
# 1  BBG000Q7ZZY2   UNAC       TQBR 2018-03-07 18:48:00+00:00      rub
# 2  TCS00A10ANA1   CNRU       TQBR 2021-11-05 17:00:00+00:00      rub
# 3  TCS00A106YF0   VKCO       TQBR 2020-07-02 06:59:00+00:00      rub
# 4  BBG004RVFCY3   MGNT       TQBR 2018-03-07 18:33:00+00:00      rub
#
#                                        name
# 0                              ВСМПО-АВИСМА
# 1  Объединенная авиастроительная корпорация
# 2                                      Циан
# 3                                        ВК
# 4                                    Магнит

# %%
shares_df.loc[0, 'figi']
# Out:
# 'BBG004S68CV8'

# %%
with Client(t_sandbox_token) as client:
    for candle in client.get_all_candles(
            figi=shares_df.loc[0, 'figi'],
            from_=now() - timedelta(days=10),
            to = now(),
            interval = CandleInterval.CANDLE_INTERVAL_DAY,
        ):
        print(candle)
# Out:
# HistoricCandle(open=Quotation(units=31740, nano=0), high=Quotation(units=31820, nano=0), low=Quotation(units=30260, nano=0), close=Quotation(units=30740, nano=0), volume=1116, time=datetime.datetime(2025, 5, 26, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30560, nano=0), high=Quotation(units=30900, nano=0), low=Quotation(units=29880, nano=0), close=Quotation(units=30800, nano=0), volume=910, time=datetime.datetime(2025, 5, 27, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30780, nano=0), high=Quotation(units=31500, nano=0), low=Quotation(units=30720, nano=0), close=Quotation(units=31260, nano=0), volume=1051, time=datetime.datetime(2025, 5, 28, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=31400, nano=0), high=Quotation(units=31420, nano=0), low=Quotation(units=30640, nano=0), close=Quotation(units=30740, nano=0), volume=759, time=datetime.datetime(2025, 5, 29, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30740, nano=0), high=Quotation(units=31280, nano=0), low=Quotation(units=30660, nano=0), close=Quotation(units=30860, nano=0), volume=929, time=datetime.datetime(2025, 5, 30, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30520, nano=0), high=Quotation(units=31140, nano=0), low=Quotation(units=30240, nano=0), close=Quotation(units=30800, nano=0), volume=817, time=datetime.datetime(2025, 6, 2, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30860, nano=0), high=Quotation(units=31220, nano=0), low=Quotation(units=30680, nano=0), close=Quotation(units=31180, nano=0), volume=964, time=datetime.datetime(2025, 6, 3, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=31020, nano=0), high=Quotation(units=31680, nano=0), low=Quotation(units=30520, nano=0), close=Quotation(units=30720, nano=0), volume=1829, time=datetime.datetime(2025, 6, 4, 0, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=30740, nano=0), high=Quotation(units=31240, nano=0), low=Quotation(units=30700, nano=0), close=Quotation(units=30900, nano=0), volume=345, time=datetime.datetime(2025, 6, 5, 0, 0, tzinfo=datetime.timezone.utc), is_complete=False, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
