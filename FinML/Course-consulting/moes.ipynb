# %%
import requests

# %%
url = "https://iss.moex.com/iss/engines/stock/markets/shares/boards/TQBR/securities/SBER/trades.json"
data = requests.get(url).json()

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['trades', 'dataversion', 'trades_yields'])

# %%
type(data['trades'])
# Out:
# dict

# %%
data['trades'].keys()
# Out:
# dict_keys(['metadata', 'columns', 'data'])

# %%
data['trades']['columns']
# Out:
# ['TRADENO',
#  'TRADETIME',
#  'BOARDID',
#  'SECID',
#  'PRICE',
#  'QUANTITY',
#  'VALUE',
#  'PERIOD',
#  'TRADETIME_GRP',
#  'SYSTIME',
#  'BUYSELL',
#  'DECIMALS',
#  'TRADINGSESSION',
#  'TRADEDATE',
#  'TRADE_SESSION_DATE']

# %%
print(data["trades"]["data"][:5])
# Out:
# [[14489965189, '06:59:55', 'TQBR', 'SBER', 303.95, 1, 303.95, 'S', 659, '2025-10-20 06:59:57', 'S', 2, '0', '2025-10-20', '2025-10-20'], [14489965190, '06:59:55', 'TQBR', 'SBER', 303.95, 1, 303.95, 'S', 659, '2025-10-20 06:59:57', 'B', 2, '0', '2025-10-20', '2025-10-20'], [14489965191, '06:59:55', 'TQBR', 'SBER', 303.95, 1, 303.95, 'S', 659, '2025-10-20 06:59:57', 'B', 2, '0', '2025-10-20', '2025-10-20'], [14489965192, '06:59:55', 'TQBR', 'SBER', 303.95, 10, 3039.5, 'S', 659, '2025-10-20 06:59:57', 'B', 2, '0', '2025-10-20', '2025-10-20'], [14489965193, '06:59:55', 'TQBR', 'SBER', 303.95, 1, 303.95, 'S', 659, '2025-10-20 06:59:57', 'B', 2, '0', '2025-10-20', '2025-10-20']]

# %%
url = "https://iss.moex.com/iss/securities/SBER.json"
data = requests.get(url).json()

# %%
data.keys()
# Out:
# dict_keys(['description', 'boards'])

# %%
data['boards']['columns']
# Out:
# ['secid',
#  'boardid',
#  'title',
#  'board_group_id',
#  'market_id',
#  'market',
#  'engine_id',
#  'engine',
#  'is_traded',
#  'decimals',
#  'history_from',
#  'history_till',
#  'listed_from',
#  'listed_till',
#  'is_primary',
#  'currencyid',
#  'unit']
