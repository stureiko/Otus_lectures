# %%
from dotenv import load_dotenv
import os
import logging
import backtrader as bt
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import hmac
import hashlib
from datetime import datetime, timedelta
import json
import threading
from typing import Dict, Optional, List

from pybit.unified_trading import HTTP

# %%
load_dotenv(override=True)
# Out:
# True

# %%
bybit_api_key = os.getenv("BYBIT_API_KEY")
bybit_secret_key = os.getenv('BYBIT_API_SECRET')


if bybit_api_key == None or bybit_secret_key == None:
    raise ValueError('API key not found')

# bybit_api_key, bybit_secret_key

# %%
session = HTTP(
    testnet=True,
    demo=True,
    api_key=bybit_api_key,
    api_secret=bybit_secret_key,
)

# %%
session.get_instruments_info(
    category="linear",
    symbol="BTCUSDT",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': 'BTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1585526400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '100.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.10',
#      'maxPrice': '1999999.80',
#      'tickSize': '0.10'},
#     'lotSizeFilter': {'maxOrderQty': '1190.000',
#      'minOrderQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '1190.000',
#      'maxMktOrderQty': '500.000',
#      'minNotionalValue': '5'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT',
#     'copyTrading': 'both',
#     'upperFundingRate': '0.005',
#     'lowerFundingRate': '-0.005',
#     'isPreListing': False,
#     'preListingInfo': None,
#     'riskParameters': {'priceLimitRatioX': '0.01', 'priceLimitRatioY': '0.02'},
#     'displayName': ''}],
#   'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1758130790321}

# %%
session.get_orderbook(category="linear", symbol="BTCUSDT")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'s': 'BTCUSDT',
#   'b': [['160679.7', '0.001'],
#    ['160287.6', '0.001'],
#    ['159987.8', '0.001'],
#    ['159630.8', '0.001'],
#    ['159069.6', '0.001'],
#    ['158958.5', '0.001'],
#    ['158396', '0.001'],
#    ['158300', '0.263'],
#    ['158280.8', '0.001'],
#    ['158080', '0.001'],
#    ['158047.4', '0.001'],
#    ['157851.6', '0.001'],
#    ['157597.3', '0.001'],
#    ['156828.7', '0.001'],
#    ['156633.6', '0.001'],
#    ['156154.6', '0.001'],
#    ['155563.8', '0.001'],
#    ['155415.6', '0.001'],
#    ['155376.5', '0.001'],
#    ['154545.8', '0.004'],
#    ['154545.7', '3.838'],
#    ['154517.6', '9'],
#    ['154464.5', '8.915'],
#    ['154410.9', '8.998'],
#    ['154261.8', '0.001']],
#   'a': [['160952.6', '0.001'],
#    ['161185', '0.001'],
#    ['161656', '0.001'],
#    ['161756', '0.001'],
#    ['161833', '0.001'],
#    ['161926.5', '0.004'],
#    ['161992.9', '0.001'],
#    ['162045.3', '0.001'],
#    ['162150.7', '0.003'],
#    ['162384.9', '0.001'],
#    ['162637.1', '0.001'],
#    ['163530.4', '0.068'],
#    ['163544', '0.001'],
#    ['163697.9', '0.001'],
#    ['163725.8', '0.001'],
#    ['163848.7', '0.003'],
#    ['163882.2', '0.001'],
#    ['164089.2', '0.001'],
#    ['164855.5', '0.001'],
#    ['165475.6', '0.001'],
#    ['165541.4', '0.001'],
#    ['165546.6', '0.003'],
#    ['165618.5', '0.001'],
#    ['165731.4', '0.001'],
#    ['166993.5', '0.001']],
#   'ts': 1758130810369,
#   'u': 507210,
#   'seq': 9517946946,
#   'cts': 1758130810334},
#  'retExtInfo': {},
#  'time': 1758130810493}

# %%
session.get_tickers(
    category="spot",
    symbol="ETHUSDT",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'spot',
#   'list': [{'symbol': 'ETHUSDT',
#     'bid1Price': '5325.91',
#     'bid1Size': '0.0015',
#     'ask1Price': '5490.52',
#     'ask1Size': '0.00403',
#     'lastPrice': '5406.24',
#     'prevPrice24h': '5377.27',
#     'price24hPcnt': '0.0054',
#     'highPrice24h': '5500.46',
#     'lowPrice24h': '4598.42',
#     'turnover24h': '3286.5956926',
#     'volume24h': '0.63411',
#     'usdIndexPrice': '4510.941813'}]},
#  'retExtInfo': {},
#  'time': 1758130835501}

# %%
session.get_risk_limit(
    category="inverse",
    symbol="BTCUSD",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'inverse',
#   'list': [{'id': 1,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '150',
#     'maintenanceMargin': '0.005',
#     'initialMargin': '0.01',
#     'isLowestRisk': 1,
#     'maxLeverage': '100.00',
#     'mmDeduction': ''},
#    {'id': 2,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '300',
#     'maintenanceMargin': '0.01',
#     'initialMargin': '0.015',
#     'isLowestRisk': 0,
#     'maxLeverage': '66.67',
#     'mmDeduction': '0.75'},
#    {'id': 3,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '450',
#     'maintenanceMargin': '0.015',
#     'initialMargin': '0.02',
#     'isLowestRisk': 0,
#     'maxLeverage': '50.00',
#     'mmDeduction': '2.25'},
#    {'id': 4,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '600',
#     'maintenanceMargin': '0.02',
#     'initialMargin': '0.025',
#     'isLowestRisk': 0,
#     'maxLeverage': '40.00',
#     'mmDeduction': '4.5'},
#    {'id': 5,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '750',
#     'maintenanceMargin': '0.0225',
#     'initialMargin': '0.03',
#     'isLowestRisk': 0,
#     'maxLeverage': '33.34',
#     'mmDeduction': '6'},
#    {'id': 6,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '900',
#     'maintenanceMargin': '0.025',
#     'initialMargin': '0.035',
#     'isLowestRisk': 0,
#     'maxLeverage': '28.58',
#     'mmDeduction': '7.875'},
#    {'id': 7,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '1050',
#     'maintenanceMargin': '0.0275',
#     'initialMargin': '0.04',
#     'isLowestRisk': 0,
#     'maxLeverage': '25.00',
#     'mmDeduction': '10.125'},
#    {'id': 8,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '1200',
#     'maintenanceMargin': '0.03',
#     'initialMargin': '0.045',
#     'isLowestRisk': 0,
#     'maxLeverage': '22.23',
#     'mmDeduction': '12.75'},
#    {'id': 9,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '1350',
#     'maintenanceMargin': '0.0325',
#     'initialMargin': '0.05',
#     'isLowestRisk': 0,
#     'maxLeverage': '20.00',
#     'mmDeduction': '15.75'},
#    {'id': 10,
#     'symbol': 'BTCUSD',
#     'riskLimitValue': '1500',
#     'maintenanceMargin': '0.035',
#     'initialMargin': '0.055',
#     'isLowestRisk': 0,
#     'maxLeverage': '18.19',
#     'mmDeduction': '19.125'}],
#   'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1758127888964}

# %%
session.get_instruments_info(
    category="linear",
    symbol="BTCUSDT",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': 'BTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1585526400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '100.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.10',
#      'maxPrice': '1999999.80',
#      'tickSize': '0.10'},
#     'lotSizeFilter': {'maxOrderQty': '1190.000',
#      'minOrderQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '1190.000',
#      'maxMktOrderQty': '500.000',
#      'minNotionalValue': '5'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT',
#     'copyTrading': 'both',
#     'upperFundingRate': '0.005',
#     'lowerFundingRate': '-0.005',
#     'isPreListing': False,
#     'preListingInfo': None,
#     'riskParameters': {'priceLimitRatioX': '0.01', 'priceLimitRatioY': '0.02'},
#     'displayName': ''}],
#   'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1758127889236}

# %%
session.get_historical_volatility(
    category="option",
    baseCoin="ETH",
    period=30,
)
# Out:
# {'retCode': 0,
#  'retMsg': 'SUCCESS',
#  'category': 'option',
#  'result': [{'period': 30, 'value': '0.62605784', 'time': '1758124800000'}]}
