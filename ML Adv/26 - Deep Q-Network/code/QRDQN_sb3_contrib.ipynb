# %%
import gymnasium as gym
from sb3_contrib import QRDQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Создание среды
env = gym.make("CartPole-v1")

# Создание модели QR-DQN
model = QRDQN(
    policy="MlpPolicy",
    env=env,
    learning_rate=1e-3,
    buffer_size=100_000,
    learning_starts=1_000,
    batch_size=32,
    tau=1.0,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1_000,
    verbose=0,
    tensorboard_log="./sb3_log/",
)

# %%
# Обучение модели
model.learn(total_timesteps=int(2e5), 
            progress_bar=True, 
            tb_log_name="qrdqn_run",
            )
# Out:
# Output()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Обучение модели
# ----> 2 model.learn(total_timesteps=int(2e5),
#       3             progress_bar=True,
#       4             tb_log_name="qrdqn_run",
#       5             )
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/sb3_contrib/qrdqn/qrdqn.py:278, in QRDQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     269 def learn(
#     270     self: SelfQRDQN,
#     271     total_timesteps: int,
#    (...)    276     progress_bar: bool = False,
#     277 ) -> SelfQRDQN:
# --> 278     return super().learn(
#     279         total_timesteps=total_timesteps,
#     280         callback=callback,
#     281         log_interval=log_interval,
#     282         tb_log_name=tb_log_name,
#     283         reset_num_timesteps=reset_num_timesteps,
#     284         progress_bar=progress_bar,
#     285     )
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/sb3_contrib/qrdqn/qrdqn.py:224, in QRDQN.train(self, gradient_steps, batch_size)
#     222 # Optimize the policy
#     223 self.policy.optimizer.zero_grad()
# --> 224 loss.backward()
#     225 # Clip gradient norm
#     226 if self.max_grad_norm is not None:
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
evaluate_policy(model=model,
                env=env)
# Out:
# /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (9.4, 0.66332495807108)
