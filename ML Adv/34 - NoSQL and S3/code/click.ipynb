# %%
import clickhouse_connect

# %%
client = clickhouse_connect.get_client(host='localhost')

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',), ('default',), ('information_schema',), ('system',)]

# %%
result = client.query('CREATE DATABASE IF NOT EXISTS test_database')
result.result_rows
# Out:
# [[4481917, 'cc89866d-edc9-4eb2-acdd-b1e86a4812c1']]

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',),
#  ('default',),
#  ('information_schema',),
#  ('system',),
#  ('test_database',)]

# %%
client.query('USE test_database')

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[6631333, 'cbec6468-1f3c-4564-b561-b78d6ab94363']]

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_database.test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[5639417, '128d385c-47c3-4447-93ea-0b547c246993']]

# %%
result = client.query('SHOW TABLES FROM test_database')
result.result_rows
# Out:
# [('test_table',)]

# %%
q = '''
INSERT INTO test_database.test_table (id, name) VALUES
(1, 'Name 1'),
(2, 'Name 2')
'''
result = client.query(q)
result.result_rows
# Out:
# []

# %%
result = client.query('SELECT * FROM test_database.test_table')
result.result_rows
# Out:
# [(1, 'Name 1'), (2, 'Name 2')]
