# %%
import random
from typing import List

# %% [markdown]
# ## Задача
# Есть массив чисел. Все числа представлены два раза, за исключением одного. Задача найти это одинокое число.

# %%
# Создадим массив
size = 10_000
input_array = []
for item in range(size):
    input_array.append(item)
    if item != 42:
        input_array.append(item)

random.shuffle(input_array)

# %%
input_array[:10]
# Out:
# [3537, 9372, 1694, 5572, 6963, 9835, 1911, 7252, 6217, 8976]

# %% [markdown]
# ## Bruteforce

# %%
def bruteforce_find(arr: List) -> int:
    for i in range(len(arr)):
        is_alone = True
        for j in range(len(arr)):
            if i != j and arr[i] == arr[j]:
                is_alone = False
                break
        if is_alone:
            return arr[i]

# %%
# %%time
bruteforce_find(input_array)
# Out:
# CPU times: user 1.74 s, sys: 8.42 ms, total: 1.75 s
# Wall time: 1.82 s
# 42

# %%
# %%timeit
bruteforce_find(input_array)
# Out:
# 1.71 s ± 18 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Profiling

# %% [markdown]
# ### line_profiler

# %%
# %load_ext line_profiler

# %%
# %lprun -f bruteforce_find bruteforce_find(input_array)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 34.3807 s
# File: /var/folders/lk/6f78t4jn60s5_ntqqc2dj0980000gn/T/ipykernel_46536/1480694860.py
# Function: bruteforce_find at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def bruteforce_find(arr: List) -> int:
#      2      5620    2162000.0    384.7      0.0      for i in range(len(arr)):
#      3      5620    1459000.0    259.6      0.0          is_alone = True
#      4  56088097     1.66e+10    296.8     48.4          for j in range(len(arr)):
#      5  56088096     1.77e+10    316.0     51.5              if i != j and arr[i] == arr[j]:
#      6      5619    2209000.0    393.1      0.0                  is_alone = False
#      7      5619    2513000.0    447.2      0.0                  break
#      8      5620    1613000.0    287.0      0.0          if is_alone:
#      9         1       2000.0   2000.0      0.0              return arr[i]

# %% [markdown]
# ## Оптимизированное решение

# %%
# XOR
1^1
# Out:
# 0

# %%
# XOR
56^56^76
# Out:
# 76

# %%
def opt_find(arr: List) -> int:
    res = 0
    for item in arr:
        res ^= item
    return res

# %%
# %%time
opt_find(input_array)
# Out:
# CPU times: user 764 μs, sys: 2 μs, total: 766 μs
# Wall time: 768 μs
# 42

# %%
# %%timeit
opt_find(input_array)
# Out:
# 725 μs ± 1.32 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %lprun -f opt_find opt_find(input_array)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.026236 s
# File: /var/folders/lk/6f78t4jn60s5_ntqqc2dj0980000gn/T/ipykernel_46536/2542643841.py
# Function: opt_find at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def opt_find(arr: List) -> int:
#      2         1       1000.0   1000.0      0.0      res = 0
#      3     20000   14152000.0    707.6     53.9      for item in arr:
#      4     19999   12081000.0    604.1     46.0          res ^= item
#      5         1       2000.0   2000.0      0.0      return res
