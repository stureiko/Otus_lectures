# %%
import numpy as np
from numba import jit
from numpy.typing import ArrayLike

# %%
def without_numba(x: ArrayLike) -> ArrayLike:
    trace = .0
    for i in range(x.shape[0]):
        trace += np.tanh(x[i, i])
    return x + trace

# %%
@jit(nopython=True)
def with_numba(x: ArrayLike) -> ArrayLike:
    trace = .0
    for i in range(x.shape[0]):
        trace += np.tanh(x[i, i])
    return x + trace

# %%
x = np.arange(1000000).reshape(1000, 1000)

# %%
# %%time
_ = without_numba(x)
# Out:
# CPU times: user 2.24 ms, sys: 1.78 ms, total: 4.03 ms
# Wall time: 2.8 ms

# %%
# %%timeit
_ = without_numba(x)
# Out:
# 2.01 ms ± 23.8 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%time
_ = with_numba(x)
# Out:
# CPU times: user 702 μs, sys: 463 μs, total: 1.16 ms
# Wall time: 1.17 ms

# %%
# %%timeit
_ = with_numba(x)
# Out:
# 1.19 ms ± 29.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
