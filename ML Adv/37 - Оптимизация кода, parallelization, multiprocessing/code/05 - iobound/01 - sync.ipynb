# %%
import requests
from tqdm import tqdm

# %%
url = 'http://localhost:5002'
res = []

with requests.Session() as session:
    total = session.get(url + '/total').json()['total']
    for index in tqdm(range(total)):
        res.append(session.get(url + '/texts/2').json()['text'])
# Out:
# 100%|██████████| 24704/24704 [00:29<00:00, 829.98it/s]

# %%
# %%time
url = 'http://localhost:5002'
res = []

with requests.Session() as session:
    total = session.get(url + '/total').json()['total']
    for index in tqdm(range(total)):
        res.append(session.get(url + '/texts/2').json()['text'])
# Out:
# 100%|██████████| 24704/24704 [00:26<00:00, 949.45it/s]
# CPU times: user 10.8 s, sys: 2.51 s, total: 13.3 s
# Wall time: 26.1 s
