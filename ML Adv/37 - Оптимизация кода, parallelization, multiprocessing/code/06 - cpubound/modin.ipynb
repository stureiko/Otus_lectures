# %% [markdown]
# environment: otus

# %%
import modin.pandas as md

from workload import process_text

# %%
import ray
# Look at the Ray documentation with respect to the Ray configuration suited to you most.
ray.init()
# Out:
# 2025-11-19 21:07:38,623	INFO worker.py:2003 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.12.3', ray_version='2.51.1', ray_commit='eeb38c79c1af96df29cbacab7b8a823d489237f3')
# (raylet) [2025-11-19 21:07:48,648 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2748 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:07:58,735 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2728 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:08,819 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2731 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:18,906 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.272 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:28,988 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2719 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:39,076 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2708 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:49,168 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2708 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:08:59,268 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2695 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:09,360 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2693 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:19,361 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2685 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:29,459 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2683 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:39,541 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2818 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:49,569 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2858 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:09:59,611 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.288 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:09,684 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2953 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:19,711 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2884 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:29,747 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2886 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:39,765 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2862 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:49,788 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2854 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:10:59,806 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2853 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:09,831 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2853 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:19,867 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2854 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:29,882 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2853 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:39,912 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2795 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:49,950 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2797 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:11:59,960 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2797 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:12:09,981 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2796 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:12:20,007 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2797 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:12:30,046 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2796 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:12:40,060 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2795 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:12:50,066 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2784 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:00,089 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2784 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:10,115 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2783 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:20,126 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2774 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:30,138 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2763 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:40,161 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2762 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:13:50,174 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2762 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:00,208 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2762 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:10,234 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2761 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:20,248 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.274 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:30,264 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2739 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:40,285 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2734 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:14:50,329 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2823 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:00,431 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2823 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:10,440 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2822 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:20,450 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2823 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:30,486 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2822 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:40,503 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2857 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:15:50,519 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2857 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:00,550 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2851 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:10,643 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2893 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:20,660 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2894 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:30,677 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2889 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:40,692 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2877 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.
# (raylet) [2025-11-19 21:16:50,704 E 539 2189811] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-11-19_21-07-33_942105_97048 is over 95% full, available space: 21.2982 GB; capacity: 926.352 GB. Object creation will fail if spilling is required.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/reviews.csv')
# df = df.iloc[:300]

# %%
df['review'].head(5)
# Out:
# 0    Нашумевший кинохит Анаконда не мог остаться в ...
# 1    Фильм об истории человека, который имеет все, ...
# 2    Мне все говорили 'фильм фигня', 'фильм не опра...
# 3    Итак, перед нами творение итальянского режиссе...
# 4    Одиннадцатый сезон\n\nЧто происходит после зав...
# Name: review, dtype: object

# %%
# %%time
res = df['review'].apply(process_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "res = df['review'].apply(process_text)\n")
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2545 with self.builtin_trap:
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#    2552 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/IPython/core/magics/execution.py:1390, in ExecutionMagics.time(self, line, cell, local_ns)
#    1388 st = clock2()
#    1389 try:
# -> 1390     exec(code, glob, local_ns)
#    1391     out = None
#    1392     # multi-line %%time case
#
# File <timed exec>:1
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/Documents/Programming/Otus/ML Adv/37 - Оптимизация кода, parallelization, multiprocessing/code/06 - cpubound/workload.py:13, in process_text(text)
#      12 def process_text(text: str) -> str:
# ---> 13     return ' '.join(
#      14         map(
#      15             lambda x: get_normal_form(str(x)), \
#      16             regexp.findall(text)
#      17         )
#      18     )
#
# File ~/Documents/Programming/Otus/ML Adv/37 - Оптимизация кода, parallelization, multiprocessing/code/06 - cpubound/workload.py:15, in process_text.<locals>.<lambda>(x)
#      12 def process_text(text: str) -> str:
#      13     return ' '.join(
#      14         map(
# ---> 15             lambda x: get_normal_form(str(x)), \
#      16             regexp.findall(text)
#      17         )
#      18     )
#
# File ~/Documents/Programming/Otus/ML Adv/37 - Оптимизация кода, parallelization, multiprocessing/code/06 - cpubound/workload.py:10, in get_normal_form(world)
#       9 def get_normal_form(world: str) -> str:
# ---> 10     return morph.parse(world)[0].normal_form
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pymorphy3/analyzer.py:321, in MorphAnalyzer.parse(self, word)
#     318         break
#     320 if self.prob_estimator is not None:
# --> 321     res = self.prob_estimator.apply_to_parses(word, word_lower, res)
#     323 if self._result_type is None:
#     324     return res
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pymorphy3/analyzer.py:77, in ProbabilityEstimator.apply_to_parses(self, word, word_lower, parses)
#      74 if not parses:
#      75     return parses
# ---> 77 probs = [self.p_t_given_w.prob(word_lower, tag)
#      78         for (word, tag, normal_form, score, methods_stack) in parses]
#      80 if sum(probs) == 0:
#      81     # no P(t|w) information is available; return normalized estimate
#      82     k = 1.0 / sum(map(_score_getter, parses))
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/pymorphy3/dawg.py:66, in ConditionalProbDistDAWG.prob(self, word, tag)
#      64 def prob(self, word, tag):
#      65     dawg_key = "%s:%s" % (word, tag)
# ---> 66     return self.get(dawg_key, 0) / self.MULTIPLIER
#
# File /opt/miniconda3/envs/otus_new/lib/python3.12/site-packages/dawg_python/dawgs.py:447, in IntDAWG.get(self, key, default)
#     444         raise KeyError(key)
#     445     return res
# --> 447 def get(self, key, default=None):
#     448     """
#     449     Return value for the given key or ``default`` if the key is not found.
#     450     """
#     451     if not isinstance(key, bytes):
#
# KeyboardInterrupt:

# %%
ray.shutdown()
