# %% [markdown]
# # NumPy - работа с массивами

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Исходные данные

# %%
days = np.arange(365)
t = np.cos((days/days.shape*2 - 1)*np.pi)*20 + np.random.randn(365)*5  # температура

# %%
plt.plot(days, t)
plt.title('Годовой график температуры')
plt.xlabel('День года')
plt.ylabel('Температура')
plt.show()

# %% [markdown]
# ## Повторяемость эксперимента
#
# Дополните код, чтобы исходные данные после каждого запуска были неизменными

# %%
# your code here

# %% [markdown]
# ## Статистика и индексация
# Найдите:
# - Среднюю, медианную и стандартную температуру.
# - Минимальное и максимальное значение и соответствующие индексы.

# %%
# your code here

# %% [markdown]
# ## Фильтрация
# Найдите:
# - Дни, когда температура была выше средней.
# - Сколько дней было холоднее 18 градусов?

# %%
# your code here

# %% [markdown]
# ## Работа с данными
#
# - Разделите данные на недели (по 7 дней) и найдите среднюю температуру каждой недели
# - Вычислите скользящее среднее (по 7 дней) и сравните со средними для каждой недели

# %%
# your code here

# %% [markdown]
# ## Манипулирвоание массивами

# %% [markdown]
# ### Исходные данные

# %%
# Фиксируем seed для воспроизводимости
np.random.seed(42)

# Генерация списка 100 названий продуктов
adjectives = ["Fresh", "Organic", "Frozen", "Crispy", "Spicy", "Sweet", "Sour", "Salty", "Green", "Hot"]
nouns = ["Apple", "Tomato", "Milk", "Bread", "Chicken", "Cheese", "Juice", "Coffee", "Rice", "Fish"]
products = np.array([f"{adj} {noun}" for adj in adjectives for noun in nouns])

# Проверка размера
assert products.shape == (100,)

# Генерация цен: shape = (100 продуктов, 365 дней)
# Базовая цена от 10 до 100 рублей, ежедневные флуктуации ~ N(0, 2)
base_prices = np.random.uniform(10, 100, size=100).reshape(-1, 1)
daily_noise = np.random.normal(loc=0, scale=2, size=(100, 365))
prices = np.clip(base_prices + daily_noise, 1, None).round(2)  # не даём уйти ниже 1 рубля

# %% [markdown]
# ## Задание 1: Общая выручка по каждому продукту
#
# Условие:
# Считается, что каждый день продаётся по фиксированному количеству 10 единиц каждого продукта. Найдите общую выручку за год по каждому продукту с помощью скалярного произведения.

# %%
# your code here

# %% [markdown]
# ## Задание 2: День наибольшей выручки
#
# Условие:
# Определите, в какой день года суммарная выручка по всем продуктам была максимальной. То есть:
# ∑ (цена[i][d] × количество[i][d]) по всем i продуктов, где количество — случайные продажи в диапазоне [5, 20].

# %%
# your code here

# %% [markdown]
# ## Задание 3: Сравнение “средневзвешенной цены”
#
# Условие:
# Вычислите средневзвешенную цену каждого продукта за год, используя веса — количество проданных единиц (рандомно от 5 до 15 штук в день).

# %%
# your code here
