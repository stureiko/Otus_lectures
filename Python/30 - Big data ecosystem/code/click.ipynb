# %%
import clickhouse_connect

# %%
client = clickhouse_connect.get_client(host='localhost')

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',), ('default',), ('information_schema',), ('system',)]

# %%
result = client.query('CREATE DATABASE IF NOT EXISTS test_database')
result.result_rows
# Out:
# [[7011542, 'e2e991fd-697f-465a-9dbf-0de784717413']]

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',),
#  ('default',),
#  ('information_schema',),
#  ('system',),
#  ('test_database',)]

# %%
client.query('USE test_database')

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[15757333, '9fcd9810-f2f6-4117-bad1-f6b1276621d5']]

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_database.test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[1534375, '2ab3ec4f-c45f-40c3-bc65-553efe108760']]

# %%
result = client.query('SHOW TABLES FROM test_database')
result.result_rows
# Out:
# [('test_table',)]

# %%
q = '''
INSERT INTO test_database.test_table (id, name) VALUES
(1, 'Name 1'),
(2, 'Name 2')
'''
result = client.query(q)
result.result_rows
# Out:
# []

# %%
result = client.query('SELECT * FROM test_database.test_table')
result.result_rows
# Out:
# [(1, 'Name 1'), (2, 'Name 2')]
