# %%
import clickhouse_connect

# %%
client = clickhouse_connect.get_client(host='localhost')

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',), ('default',), ('information_schema',), ('system',)]

# %%
result = client.query('CREATE DATABASE IF NOT EXISTS test_database')
result.result_rows
# Out:
# [[8627250, 'ac4ff518-a4e8-4c93-96a4-fb290effb88c']]

# %%
result = client.query('SHOW DATABASES')
result.result_rows
# Out:
# [('INFORMATION_SCHEMA',),
#  ('default',),
#  ('information_schema',),
#  ('system',),
#  ('test_database',)]

# %%
client.query('USE test_database')

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[8130125, '331df510-7d7a-4926-8c26-f2f41c0ebb16']]

# %%
result = client.query(
'''CREATE TABLE IF NOT EXISTS test_database.test_table(
id UInt64 NOT NULL,
name String,
PRIMARY KEY id);
''')
result.result_rows
# Out:
# [[700625, '30950f09-be47-4e60-a1c6-1405cca16d59']]

# %%
result = client.query('SHOW TABLES FROM test_database')
result.result_rows
# Out:
# [('test_table',)]

# %%
q = '''
INSERT INTO test_database.test_table (id, name) VALUES
(1, 'Name 1'),
(2, 'Name 2')
'''
result = client.query(q)
result.result_rows
# Out:
# []

# %%
result = client.query('SELECT * FROM test_database.test_table')
result.result_rows
# Out:
# [(1, 'Name 1'), (2, 'Name 2')]
