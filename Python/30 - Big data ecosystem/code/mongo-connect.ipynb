# %% [markdown]
# # Работа с MongoDB - основы

# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db = client['my_test_database']
coll = db['my_test_collection']

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
mydict = { "name": "John", "address": "Highway 37" }

x = coll.insert_one(mydict)

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'my_test_database']

# %%
mylist = [
    { "name": "Amy", "address": "Apple st 652"},
    { "name": "Hannah", "address": "Mountain 21"},
    { "name": "Michael", "address": "Valley 345"},
    { "name": "Sandy", "address": "Ocean blvd 2"},
    { "name": "Betty", "address": "Green Grass 1"},
    { "name": "Richard", "address": "Sky st 331"},
    { "name": "Susan", "address": "One way 98"},
    { "name": "Vicky", "address": "Yellow Garden 2"},
    { "name": "Ben", "address": "Park Lane 38"},
    { "name": "William", "address": "Central st 954"},
    { "name": "Chuck", "address": "Main Road 989"},
    { "name": "Viola", "address": "Sideway 1633"}
]

# %%
x = coll.insert_many(mylist)

# %%
#print list of the _id values of the inserted documents:
for ids in x.inserted_ids:
    print(ids)
# Out:
# 67e5960fb8490a190e0fd73a
# 67e5960fb8490a190e0fd73b
# 67e5960fb8490a190e0fd73c
# 67e5960fb8490a190e0fd73d
# 67e5960fb8490a190e0fd73e
# 67e5960fb8490a190e0fd73f
# 67e5960fb8490a190e0fd740
# 67e5960fb8490a190e0fd741
# 67e5960fb8490a190e0fd742
# 67e5960fb8490a190e0fd743
# 67e5960fb8490a190e0fd744
# 67e5960fb8490a190e0fd745

# %%
# get all records
for x in coll.find():
    print(x)
# Out:
# {'_id': ObjectId('67e595f5b8490a190e0fd739'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e5960fb8490a190e0fd740'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e5960fb8490a190e0fd741'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd742'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e5960fb8490a190e0fd743'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('67e5960fb8490a190e0fd744'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e5960fb8490a190e0fd745'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %%
# limit resuts
for x in coll.find().limit(4):
    print(x)
# Out:
# {'_id': ObjectId('67e4e714a16dfed9a9c4996b'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996c'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996d'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996e'), 'name': 'Michael', 'address': 'Valley 345'}

# %%
# filter by address begins with S or further alphabetically.
myquery = { "address": { "$gt": "Ma" } }

for x in coll.find(myquery):
    print(x)
# Out:
# {'_id': ObjectId('67e4e717a16dfed9a9c4996d'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996e'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996f'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49971'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49972'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49973'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49974'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49976'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49977'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %%
# filter by address start from 'S'
myquery = { "address": { "$regex": "^S" } }

for x in coll.find(myquery):
    print(x)
# Out:
# {'_id': ObjectId('67e4e717a16dfed9a9c49971'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49977'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %%
# sort by name ascending
for x in coll.find().sort('name', 1):
    print(x)
# Out:
# {'_id': ObjectId('67e4e717a16dfed9a9c4996c'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49974'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49970'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49976'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996d'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e4e714a16dfed9a9c4996b'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996e'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49971'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e4e717a16dfed9a9c4996f'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49972'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49973'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49977'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('67e4e717a16dfed9a9c49975'), 'name': 'William', 'address': 'Central st 954'}

# %%
# sort by name descending
for x in coll.find().sort('name', -1):
    print(x)
# Out:
# {'_id': ObjectId('67e5960fb8490a190e0fd743'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('67e5960fb8490a190e0fd745'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('67e5960fb8490a190e0fd741'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd740'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e595f5b8490a190e0fd739'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e5960fb8490a190e0fd744'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('67e5960fb8490a190e0fd742'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73a'), 'name': 'Amy', 'address': 'Apple st 652'}

# %% [markdown]
# ## Вставить сложные объекты в ту же коллекцию

# %%
mydict = { "names": ["John", "Jane", "Ann"], "address": "Highway 37" }

x = coll.insert_one(mydict)

# %%
for x in coll.find():
    print(x)
# Out:
# {'_id': ObjectId('67e595f5b8490a190e0fd739'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e5960fb8490a190e0fd740'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e5960fb8490a190e0fd741'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd742'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e5960fb8490a190e0fd743'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('67e5960fb8490a190e0fd744'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e5960fb8490a190e0fd745'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('67e596d5b8490a190e0fd746'), 'names': ['John', 'Jane', 'Ann'], 'address': 'Highway 37'}

# %%
mydict = { "names": ["John", "Jane", "Ann"], "address": {'full': 'full address', 'brief': 'brief address'} }

x = coll.insert_one(mydict)

# %%
for x in coll.find():
    print(x)
# Out:
# {'_id': ObjectId('67e595f5b8490a190e0fd739'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('67e5960fb8490a190e0fd73f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('67e5960fb8490a190e0fd740'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('67e5960fb8490a190e0fd741'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('67e5960fb8490a190e0fd742'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('67e5960fb8490a190e0fd743'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('67e5960fb8490a190e0fd744'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('67e5960fb8490a190e0fd745'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('67e596d5b8490a190e0fd746'), 'names': ['John', 'Jane', 'Ann'], 'address': 'Highway 37'}
# {'_id': ObjectId('67e596e7b8490a190e0fd747'), 'names': ['John', 'Jane', 'Ann'], 'address': {'full': 'full address', 'brief': 'brief address'}}

# %% [markdown]
# [Больше примеров подробных запросов в системе MongoDB](https://www.mongodb.com/docs/manual/tutorial/query-array-of-documents/)
