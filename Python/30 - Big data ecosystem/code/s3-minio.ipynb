# %%
from minio import Minio

# %%
client = Minio(endpoint='localhost:9000',
            access_key="b6qlz3ND2HEQ7x3zygGc",
            secret_key="K21kDHaqQWkeNep9KlcFCy0blj7TEqFzMjkl2jNR",
            secure=False)

# %%
client.list_buckets()
# Out:
# [Bucket('python-test-bucket'), Bucket('stureiko')]

# %%
# The file to upload, change this path if needed
source_file = "click.ipynb"

# The destination bucket and filename on the MinIO server
bucket_name = "python-test-bucket"
destination_file = "click_1.ipynb"

# %%
# Make the bucket if it doesn't exist.
found = client.bucket_exists(bucket_name)
if not found:
    client.make_bucket(bucket_name)
    print(f'Created bucket "{bucket_name}"')
else:
    print(f'Bucket "{bucket_name}" already exists')
# Out:
# Bucket "python-test-bucket" already exists

# %%
# Upload the file, renaming it in the process
client.fput_object(
    bucket_name, destination_file, source_file,
)
print(f'"{source_file}" successfully uploaded as object, "{destination_file}" to bucket "{bucket_name}"')
# Out:
# "click.ipynb" successfully uploaded as object, "click_1.ipynb" to bucket "python-test-bucket"
