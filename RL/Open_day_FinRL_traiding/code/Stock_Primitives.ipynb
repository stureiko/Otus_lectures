# %% [markdown]
# # Торговля акциями с использованием библиотеки FinRL

# %% [markdown]
# # Содержание

# %% [markdown]
# * [1. Описание задачи](#0)
# * [2. Установка инструментов](#1)
#     * [2.1. Установка пакетов](#1.1)
#     * [2.2. Список пакетов Python](#1.2)
#     * [2.3. Импорт пакетов](#1.3)
#     * [2.4. Создание папок](#1.4)
# * [3. Загрузка данных](#2)
# * [4. Предварительная обработка данных](#3)
#     * [4.1 Импорт финансовых данных](#3.1)
#     * [4.2 Указание необходимых элементов для расчета финансовых показателей](#3.2)
#     * [4.3 Расчет финансовых показателей](#3.3)
#     * [4.4 Обработка пропущенных и некорректных значений](#3.4)
#     * [4.5 Объединение данных о ценах акций и показателей в один DataFrame](#3.5)
#     * [4.6 Расчет рыночных коэффициентов оценки с использованием ежедневных данных о ценах акций](#3.6)
# * [5. Создание среды](#4)
#     * [5.1. Разделение данных на тренировочные и тестовые](#4.1)
#     * [5.2. Пользовательская среда](#4.2)
#     * [5.3. Инициализация среды](#4.3)
# * [6. Обучение агентов DRL](#5)
# * [7. Оценка производительности методом обратного тестирования](#6)
#     * [7.1. Статистика обратного тестирования](#6.1)
#     * [7.2. График обратного тестирования](#6.2)
#     * [7.3. Базовая статистика](#6.3)
#     * [7.4. Сравнение с индексом фондового рынка](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Часть 1. Описание задачи

# %% [markdown]
# Мы будем обучать агента (Deep Reinforcement Learning - DRL) торговле акциями. Задача описывается как Марковский процесс принятия решений (MDP), и целевая функция состоит в максимизации (ожидаемой) накопленной доходности.
#
# Определяем состояние-действие-награду следующим образом:
#
# * **Состояние $s$**: Пространство состояний представляет собой восприятие агентом среды рынка. Какё трейдер-человек анализирует различную информацию, так и наш агент пассивно наблюдает множество признаков и учится взаимодействуя с рыночной средой (обычно путем воспроизведения исторических данных).
#
# * **Действие $a$**: Пространство действий включает разрешенные действия, которые агент может совершать в каждом состоянии. Например, $a \in {−1, 0, 1}$, где $−1, 0, 1$ представляют продажу, удержание и покупку. Когда действие касается нескольких акций, то $a \in {−k, ..., −1, 0, 1, ..., k}$, например, "Покупка 10 акций AAPL" или "Продажа 10 акций AAPL" - это 10 или −10 соответственно.
#
# * **Функция вознаграждения $r(s, a, s′)$**: Вознаграждение является стимулом для агента для изучения лучшей стратегии. Например, это может быть изменение стоимости портфеля при выполнении действия $a$ в состоянии $s$ и переходе в новое состояние $s'$, т.е. $r(s, a, s′) = v′ − v$, где $v′$ и $v$ представляют значения портфеля в состояниях $s'$ и $s$ соответственно.
#
# **Рыночная среда**: 30 акций, составляющих индекс Dow Jones Industrial Average (DJIA).
#
# Данные по отдельной акции, которые мы будем использовать для этого примера, получены из API Yahoo Finance. Данные содержат цены открытия, максимальные, минимальные и закрытия, а также объем торгов.

# %% [markdown]
# <a id='1'></a>
# # Часть 2. Загрузка пакетов

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Перечень пакетов, которые мы будем использовать в данной работе
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import datetime
from os.path import exists

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from finrl.main import check_and_make_directories
from pprint import pprint
from stable_baselines3.common.logger import configure
import sys
# sys.path.append("../FinRL")

import pickle

import itertools

from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

from finrl.config_tickers import DOW_30_TICKER

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Создаем служебные папки

# %%
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Часть 3. Скачиваем данные с Yahoo Finance
# Yahoo Finance предоставляет данные о акциях, финансовые новости, финансовые отчеты и т.д. Yahoo Finance бесплатен.
# * FinRL использует класс `YahooDownloader` в `FinRL-Meta` для получения данных через API Yahoo Finance.
# * Ограничение вызова: Используя общедоступное API (без аутентификации), вы ограничены 2 000 запросами в час на IP (или до общего количества 48 000 запросов в день).

# %% [markdown]
# -----
# class YahooDownloader:
#     Получение ежедневных данных о акциях из API Yahoo Finance
#
#     Attributes
#     ----------
#         start_date : str
#             начальная дата (можно изменить в файле config.py)
#         end_date : str
#             конечная дата (можно изменить в файле config.py)
#         ticker_list : list
#             список акций, которые вы хотите извлечь (можно изменить в файле config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2019-01-01'
TEST_START_DATE = '2019-01-01'
TEST_END_DATE = '2021-01-01'

# загружаем данные
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WBA']: HTTPError('HTTP Error 404: ')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (85040, 8)

# %%
# посмотрим размер скачанных данных
df.shape
# Out:
# (85040, 8)

# %%
df.head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2009-01-02   2.721687   2.730385   2.554038   2.575631  746015200
# 1      2009-01-02  40.176655  40.237952  39.332120  39.904224    6547900
# 2      2009-01-02  14.821137  14.966819  14.108066  14.238413   10955700
# 3      2009-01-02  33.941101  34.173627  32.088404  32.103406    7010200
# 4      2009-01-02  30.076941  30.121822  28.666382  28.794615    7117200
#
# Price   tic  day
# 0      AAPL    4
# 1      AMGN    4
# 2       AXP    4
# 3        BA    4
# 4       CAT    4

# %%
# преобразуем дату
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
# Отсортируем данные по дате и коду акции
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price       date      close       high        low       open     volume   tic  \
# 0     2009-01-02   2.721687   2.730385   2.554038   2.575631  746015200  AAPL
# 1     2009-01-02  40.176655  40.237952  39.332120  39.904224    6547900  AMGN
# 2     2009-01-02  14.821137  14.966819  14.108066  14.238413   10955700   AXP
# 3     2009-01-02  33.941101  34.173627  32.088404  32.103406    7010200    BA
# 4     2009-01-02  30.076941  30.121822  28.666382  28.794615    7117200   CAT
#
# Price  day
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# # Часть 4: Предобработка данных
# - Импортировать финансовые данные, загруженные из Compustat через WRDS (Wharton Research Data Service).
# - Предварительная обработка набора данных и расчет финансовых показателей.
# - Добавить эти показатели к данным о ценах, предварительно обработанным в Части 3.
# - Рассчитать показатели, связанные с ценами, такие как P/E (цена/прибыль) и P/B (цена/балансовая стоимость).

# %% [markdown]
# ## 4.1 Импорт финансовых данных

# %% [markdown]
# Квартальные финансовые данные для составляющих индекса Dow Jones загружаем с WRDS (Wharton Research Data Services) https://wrds-www.wharton.upenn.edu. Данные, для этого примера содержат информацию с 2009 по 2020 год.

# %%
# Читаем финансовые данные
url = 'https://raw.githubusercontent.com/mariko-sawada/FinRL_with_fundamental_data/main/dow_30_fundamental_wrds.csv'

fund = pd.read_csv(url)
# fund = pd.read_csv('dow_30_fundamental_wrds.csv')

# %%
# Проверим корректность загруженных данных
fund.head()
# Out:
#    gvkey  datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt  tic  ...  \
# 0   1447  19990630    1999     2   12   INDL      C      D     STD  AXP  ...
# 1   1447  19990930    1999     3   12   INDL      C      D     STD  AXP  ...
# 2   1447  19991231    1999     4   12   INDL      C      D     STD  AXP  ...
# 3   1447  20000331    2000     1   12   INDL      C      D     STD  AXP  ...
# 4   1447  20000630    2000     2   12   INDL      C      D     STD  AXP  ...
#
#   dvpsxq mkvaltq     prccq     prchq     prclq  adjex ggroup    gind gsector  \
# 0  0.225     NaN  130.1250  142.6250  114.5000    3.0   4020  402020      40
# 1  0.000     NaN  135.0000  150.6250  121.8750    3.0   4020  402020      40
# 2  0.225     NaN  166.2500  168.8750  130.2500    3.0   4020  402020      40
# 3  0.225     NaN  148.9375  169.5000  119.5000    3.0   4020  402020      40
# 4  0.080     NaN   52.1250   57.1875   43.9375    1.0   4020  402020      40
#
#     gsubind
# 0  40202010
# 1  40202010
# 2  40202010
# 3  40202010
# 4  40202010
#
# [5 rows x 647 columns]

# %% [markdown]
# ## 4.2 Определение элементов, необходимых для расчета финансовых показателей
# - Для получения более подробной информации описания данных набора данных, пожалуйста, посетите веб-сайт WRDS (https://wrds-www.wharton.upenn.edu/). Вам потребуется зарегистрироваться.

# %%
# Список элементов, используемых для расчета финансовых показателей

items = [
    'datadate',  # Дата
    'tic',  # Тикер
    'oiadpq',  # Квартальная операционная прибыль
    'revtq',  # Квартальные доходы
    'niq',  # Квартальная чистая прибыль
    'atq',  # Всего активов
    'teqq',  # Собственный капитал
    'epspiy',  # Прибыль на акцию (базовая), включая внештатные элементы
    'ceqq',  # Общий капитал
    'cshoq',  # Общее количество обыкновенных акций
    'dvpspq',  # Дивиденды на акцию
    'actq',  # Оборотные активы
    'lctq',  # Оборотные пассивы
    'cheq',  # Денежные средства и их эквиваленты
    'rectq',  # Дебиторская задолженность
    'cogsq',  # Себестоимость проданных товаров
    'invtq',  # Инвентарь
    'apq',  # Кредиторская задолженность
    'dlttq',  # Долгосрочные обязательства
    'dlcq',  # Задолженность по текущим обязательствам
    'ltq'  # Пассивы
]

# Пропущены элементы, которые не будут использоваться
fund_data = fund[items]

# %%
# Переименование названий столбцов для удобства
fund_data = fund_data.rename(columns={
    'datadate': 'date',  # Дата
    'oiadpq': 'op_inc_q',  # Квартальная операционная прибыль
    'revtq': 'rev_q',  # Квартальные доходы
    'niq': 'net_inc_q',  # Квартальная чистая прибыль
    'atq': 'tot_assets',  # Активы
    'teqq': 'sh_equity',  # Собственный капитал
    'epspiy': 'eps_incl_ex',  # Прибыль на акцию (базовая), включая внештатные элементы
    'ceqq': 'com_eq',  # Общий капитал
    'cshoq': 'sh_outstanding',  # Общее количество обыкновенных акций
    'dvpspq': 'div_per_sh',  # Дивиденды на акцию
    'actq': 'cur_assets',  # Оборотные активы
    'lctq': 'cur_liabilities',  # Оборотные пассивы
    'cheq': 'cash_eq',  # Денежные средства и их эквиваленты
    'rectq': 'receivables',  # Дебиторская задолженность
    'cogsq': 'cogs_q',  # Себестоимость проданных товаров
    'invtq': 'inventories',  # Инвентарь
    'apq': 'payables',  # Кредиторская задолженность
    'dlttq': 'long_debt',  # Долгосрочные обязательства
    'dlcq': 'short_debt',  # Задолженность по текущим обязательствам
    'ltq': 'tot_liabilities'  # Пассивы
})

# %%
# Check the data
fund_data.head()
# Out:
#        date  tic  op_inc_q   rev_q  net_inc_q  tot_assets  sh_equity  \
# 0  19990630  AXP     896.0  5564.0      646.0    132452.0     9762.0
# 1  19990930  AXP     906.0  5584.0      648.0    132616.0     9744.0
# 2  19991231  AXP     845.0  6009.0      606.0    148517.0    10095.0
# 3  20000331  AXP     920.0  6021.0      656.0    150662.0    10253.0
# 4  20000630  AXP    1046.0  6370.0      740.0    148553.0    10509.0
#
#    eps_incl_ex   com_eq  sh_outstanding  ...  cur_assets  cur_liabilities  \
# 0         2.73   9762.0           449.0  ...         NaN              NaN
# 1         4.18   9744.0           447.6  ...         NaN              NaN
# 2         5.54  10095.0           446.9  ...         NaN              NaN
# 3         1.48  10253.0           444.7  ...         NaN              NaN
# 4         1.05  10509.0          1333.0  ...         NaN              NaN
#
#    cash_eq  receivables  cogs_q  inventories  payables  long_debt  short_debt  \
# 0   6096.0      46774.0  4668.0        448.0   22282.0     7005.0     24785.0
# 1   5102.0      48827.0  4678.0        284.0   23587.0     6720.0     24683.0
# 2  10391.0      54033.0  5164.0        277.0   25719.0     4685.0     32437.0
# 3   7425.0      53663.0  5101.0        315.0   26379.0     5670.0     29342.0
# 4   6841.0      54286.0  5324.0        261.0   29536.0     5336.0     26170.0
#
#    tot_liabilities
# 0         122690.0
# 1         122872.0
# 2         138422.0
# 3         140409.0
# 4         138044.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 4.3 Расчет финансовых показателей
# - Для элементов из отчетов о прибылях и убытках мы рассчитываем LTM (Последние двенадцать месяцев) и используем их для выведения показателей, связанных с прибылью, таких как операционная маржа и ROE. Для элементов из балансов мы используем числа на определенный день.
# - Для проверки определений расчитываемых здесь финансовых показателей, пожалуйста, обратитесь к веб-сайту CFI: https://corporatefinanceinstitute.com/resources/knowledge/finance/financial-ratios/

# %% [markdown]
# Используя имеющиеся показатели, мы рассчитываем 15 финансовых коэффициентов для отражения финансового состояния компаний. Список коэффициентов приведен ниже:
# - Коэффициенты прибыльности: Операционная маржа, Чистая маржа, Рентабельность собственного капитала, Рентабельность активов
# - Коэффициенты ликвидности: Текущая ликвидность, Коэффициент наличности, Быстрая ликвидность
# - Коэффициенты эффективности: Коэффициент оборачиваемости запасов, Коэффициент оборачиваемости кредиторской задолженности, Коэффициент оборачиваемости дебиторской задолженности
# - Финансовые коэффициенты кредитного плеча: Коэффициент долга, Коэффициент долга к собственному капиталу
# - Коэффициенты оценки рынка: P/E, P/B, Дивидендная доходность
#
# Нам необходимо рассчитать LTM (Последние двенадцать месяцев) для показателей из отчетов о прибылях и убытках, так как мы работаем с квартальными данными. Мы используем значения показателей из балансов, так как они представляют собой числа акций. Например, мы хотим рассчитать ROE к концу третьего квартала в финансовом году 2018 года. В числителе мы суммируем данные о чистой прибыли за четыре квартала.
# (Числитель ROE) = Чистая прибыль Q4 2017 года + Q1 2018 года + Q2 2018 года + Q3 2018 года
#
# Мы используем количество собственного капитала в качестве знаменателя на конец Q3 2018 года. То есть,
# (Знаменатель ROE) = Собственный капитал на конец Q3 2018 года
#
# Поскольку у нас еще нет данных о ценах на акции в DataFrame, мы рассчитываем только показатели на акцию, такие как прибыль на акцию, для расчета коэффициентов оценки рынка в конце этой части предварительной обработки.

# %% [markdown]
# Операционная маржа рассчитывается как отношение операционной прибыли к выручке и выражается в процентах.
#
# Формула для расчета операционной маржи:
# $$
# \text{Operating Margin} = \frac{\text{Операционная прибыль}}{\text{Выручка}} \times 100\%
# $$
# Этот показатель позволяет оценить эффективность компании в генерации прибыли от своей основной деятельности. Величина операционной маржи показывает, сколько долларов операционной прибыли компания генерирует на каждый доллар выручки. Более высокие значения операционной маржи обычно указывают на более эффективное управление расходами и более высокую прибыльность бизнеса.

# %% [markdown]
# ### Чистая прибыль к выручке (Чистая операционная маржа)
#
# Чистая операционная маржа рассчитывается как отношение чистой прибыли к выручке и выражается в процентах.
#
# Формула для расчета чистой операционной маржи:
#
# $$
# \text{Net Profit Margin} = \frac{\text{Чистая прибыль}}{\text{Выручка}} \times 100\%
# $$
#
# Этот показатель позволяет оценить, какая часть выручки превращается в чистую прибыль после учета всех операционных и неоперационных расходов. Чистая операционная маржа является важным показателем финансовой устойчивости и эффективности бизнеса. Высокие значения этого показателя свидетельствуют о том, что компания эффективно управляет своими расходами и генерирует значительную прибыль от своей деятельности.

# %% [markdown]
# ### Рентабельность активов (ROA)
#
# Рентабельность активов (ROA) рассчитывается как отношение чистой прибыли к общей сумме активов и выражается в процентах.
#
# Формула для расчета ROA:
#
# $$
# \text{Return On Assets (ROA)} = \frac{\text{Чистая прибыль}}{\text{Общая сумма активов}} \times 100\%
# $$
#
# ROA показывает, сколько прибыли компания генерирует на каждый доллар активов. Этот показатель помогает инвесторам и аналитикам оценить эффективность использования активов компанией для генерации прибыли. Более высокие значения ROA указывают на более эффективное использование активов и, как следствие, на более высокую прибыльность компании.

# %% [markdown]
# ### Рентабельность собственного капитала (ROE)
#
# Рентабельность собственного капитала (ROE) рассчитывается как отношение чистой прибыли к собственному капиталу и выражается в процентах.
#
# Формула для расчета ROE:
#
# $$
# \text{Return On Equity (ROE)} = \frac{\text{Чистая прибыль}}{\text{Собственный капитал}} \times 100\%
# $$
#
# ROE показывает, какую чистую прибыль компания генерирует на каждый доллар собственного капитала. Этот показатель помогает инвесторам и аналитикам оценить эффективность использования собственного капитала компанией для генерации прибыли. Более высокие значения ROE обычно указывают на более эффективное использование собственного капитала и, как следствие, на более высокую прибыльность компании.

# %% [markdown]
# ### Прибыль на акцию (EPS)
#
# Прибыль на акцию (EPS) рассчитывается как отношение чистой прибыли к общему количеству обыкновенных акций компании.
#
# Формула для расчета EPS:
#
# $$
# \text{Earnings Per Share (EPS)} = \frac{\text{Чистая прибыль}}{\text{Общее количество обыкновенных акций}}
# $$
#
# EPS показывает, сколько долларов чистой прибыли приходится на одну акцию компании. Этот показатель является важным для инвесторов и аналитиков при оценке прибыльности и стоимости акций компании.

# %% [markdown]
# ### Собственный капитал на акцию (Book Value Per Share)
#
# Собственный капитал на акцию (Book Value Per Share) рассчитывается как отношение общего собственного капитала компании к общему количеству обыкновенных акций.
#
# Формула для расчета Book Value Per Share:
#
# $$
# \text{Book Value Per Share} = \frac{\text{Собственный капитал}}{\text{Общее количество обыкновенных акций}}
# $$
#
# Book Value Per Share показывает, сколько долларов собственного капитала приходится на одну акцию компании. Этот показатель используется для оценки стоимости акций и может служить важным индикатором при принятии инвестиционных решений.

# %% [markdown]
# ### Дивиденды на акцию (Dividends Per Share)
#
# Дивиденды на акцию (Dividends Per Share) рассчитываются как отношение общей суммы выплаченных дивидендов к общему количеству обыкновенных акций.
#
# Формула для расчета Dividends Per Share:
#
# $$
# \text{Dividends Per Share} = \frac{\text{Общая сумма выплаченных дивидендов}}{\text{Общее количество обыкновенных акций}}
# $$
#
# Dividends Per Share показывает, сколько долларов дивидендов выплачено на одну акцию компании. Этот показатель является важным для инвесторов, которые оценивают потенциальную доходность от дивидендов в связи с инвестициями в акции компании.

# %% [markdown]
# ### Коэффициенты ликвидности
#
# Коэффициенты ликвидности используются для оценки способности компании погасить свои текущие обязательства за счет доступных у нее активов. Они помогают инвесторам и кредиторам оценить финансовую устойчивость компании и ее способность к платежеспособности.
#
# Наиболее распространенными коэффициентами ликвидности являются:
#
# 1. **Коэффициент текущей ликвидности (Current Ratio)**:
# $$
# \text{Current Ratio} = \frac{\text{Оборотные активы}}{\text{Оборотные пассивы}}
# $$
# Этот коэффициент показывает, сколько долларов оборотных активов приходится на один доллар оборотных пассивов. Чем выше значение этого коэффициента, тем лучше, так как это указывает на то, что у компании достаточно средств для покрытия своих текущих обязательств.
#
# 2. **Быстрый коэффициент ликвидности (Quick Ratio)**:
# $$
# \text{Quick Ratio} = \frac{\text{Оборотные активы} - \text{Запасы}}{\text{Оборотные пассивы}}
# $$
# Этот коэффициент исключает запасы из оборотных активов, поскольку запасы могут быть менее ликвидными и могут быть труднее реализовать. Таким образом, Quick Ratio предоставляет оценку ликвидности компании без учета запасов.
#
# 3. **Коэффициент абсолютной ликвидности (Absolute Liquidity Ratio)**:
# $$
# \text{Absolute Liquidity Ratio} = \frac{\text{Денежные средства и эквиваленты}}{\text{Оборотные пассивы}}
# $$
# Этот коэффициент показывает, какая доля оборотных пассивов компании покрывается ее денежными средствами и эквивалентами. Он оценивает способность компании к немедленному погашению текущих обязательств.
#
# 4. **Коэффициент денежной ликвидности (Cash Ratio)**
#
# Коэффициент денежной ликвидности (Cash Ratio) - это мера ликвидности, которая оценивает способность компании погасить текущие обязательства только за счет ее наличных средств и их эквивалентов.
#
# Формула для расчета Cash Ratio:
# $$
# \text{Cash Ratio} = \frac{\text{Денежные средства и их эквиваленты}}{\text{Оборотные пассивы}}
# $$
#
# Этот коэффициент показывает, какая часть оборотных пассивов компании покрывается ее наличными средствами и их эквивалентами. Более высокое значение коэффициента денежной ликвидности указывает на более высокую способность компании погасить свои текущие обязательства без необходимости привлечения дополнительных источников финансирования.

# %% [markdown]
# ### Коэффициенты эффективности капитала
# 1. **Коэффициент оборачиваемости запасов (Inventory Turnover Ratio)**
#
# Коэффициент оборачиваемости запасов (Inventory Turnover Ratio) измеряет, сколько раз за определенный период времени компания обновляет свой инвентарь. Этот показатель помогает оценить эффективность управления запасами компании и их оборачиваемость.
#
# Формула для расчета Inventory Turnover Ratio:
# $$
# \text{Inventory Turnover Ratio} = \frac{\text{Себестоимость проданных товаров}}{\text{Средний объем запасов}}
# $$
#
# Где:
# - Себестоимость проданных товаров представляет собой затраты, связанные с производством или приобретением товаров, которые были реализованы за рассматриваемый период времени.
# - Средний объем запасов можно рассчитать как среднее арифметическое между начальным и конечным объемом запасов за период.
#
# Высокий коэффициент оборачиваемости запасов обычно указывает на то, что компания эффективно управляет своим инвентарем, что может свидетельствовать о более здоровой финансовой позиции. Однако низкий коэффициент оборачиваемости запасов может указывать на проблемы с управлением запасами или на недостаточный спрос на товары компании.
#
# 2. **Коэффициент оборачиваемости дебиторской задолженности (Receivables Turnover Ratio)**
#
# Коэффициент оборачиваемости дебиторской задолженности (Receivables Turnover Ratio) измеряет, сколько раз за определенный период времени компания обновляет свою дебиторскую задолженность. Этот показатель помогает оценить эффективность управления кредитными отношениями компании и скорость взыскания долгов.
#
# Формула для расчета Receivables Turnover Ratio:
# $$
# \text{Receivables Turnover Ratio} = \frac{\text{Выручка}}{\text{Средний объем дебиторской задолженности}}
# $$
#
# Где:
# - Выручка представляет собой общий объем продаж компании за рассматриваемый период времени.
# - Средний объем дебиторской задолженности можно рассчитать как среднее арифметическое между начальным и конечным объемом дебиторской задолженности за период.
#
# Высокий коэффициент оборачиваемости дебиторской задолженности обычно указывает на то, что компания эффективно управляет кредитными отношениями и активно взыскивает долги. Однако низкий коэффициент оборачиваемости дебиторской задолженности может свидетельствовать о проблемах с взысканием долгов или о неэффективном управлении кредитными отношениями.
#
# 3. **Коэффициент оборачиваемости кредиторской задолженности (Payable Turnover Ratio)**
#
# Коэффициент оборачиваемости кредиторской задолженности (Payable Turnover Ratio) измеряет, сколько раз за определенный период времени компания обновляет свою кредиторскую задолженность. Этот показатель помогает оценить эффективность управления кредиторскими отношениями компании и ее скорость выплаты долгов.
#
# Формула для расчета Payable Turnover Ratio:
# $$
# \text{Payable Turnover Ratio} = \frac{\text{Себестоимость проданных товаров}}{\text{Средний объем кредиторской задолженности}}
# $$
#
# Где:
# - Себестоимость проданных товаров представляет собой затраты, связанные с производством или приобретением товаров, которые были реализованы за рассматриваемый период времени.
# - Средний объем кредиторской задолженности можно рассчитать как среднее арифметическое между начальным и конечным объемом кредиторской задолженности за период.
#
# Высокий коэффициент оборачиваемости кредиторской задолженности обычно указывает на то, что компания активно выплачивает свои долги поставщикам. Однако низкий коэффициент оборачиваемости кредиторской задолженности может свидетельствовать о проблемах с платежами или о неэффективном управлении кредиторскими отношениями.

# %% [markdown]
# ### Финансовые коэффициенты кредитного плеча (Leverage Financial Ratios)
#
# Финансовые коэффициенты кредитного плеча используются для оценки уровня финансового долга компании и ее способности управлять им. Эти показатели позволяют инвесторам и кредиторам оценить финансовую устойчивость компании и ее риск в отношении обязательств.
#
# Наиболее распространенные финансовые коэффициенты кредитного плеча включают:
#
# 1. **Коэффициент финансового плеча (Debt-to-Equity Ratio)**:
# $$
# \text{Debt-to-Equity Ratio} = \frac{\text{Общий долг}}{\text{Собственный капитал}}
# $$
# Этот коэффициент показывает, сколько долларов долга приходится на один доллар собственного капитала. Он позволяет оценить, в какой степени компания финансируется за счет долга по сравнению с собственным капиталом.
#
# 2. **Коэффициент финансовой нагрузки (Financial Leverage Ratio)**:
# $$
# \text{Financial Leverage Ratio} = \frac{\text{Общий долг}}{\text{Общие активы}}
# $$
# Этот коэффициент показывает, какая часть активов компании финансируется за счет долга. Он помогает определить степень риска, связанного с использованием долгового финансирования.
#
# 3. **Коэффициент краткосрочной ликвидности (Short-term Debt Ratio)**:
# $$
# \text{Short-term Debt Ratio} = \frac{\text{Краткосрочный долг}}{\text{Общий долг}}
# $$
# Этот коэффициент показывает, какая доля долга компании является краткосрочным. Он помогает оценить финансовую стабильность компании в краткосрочной перспективе.
#
# 4. **Коэффициент капитализации долга (Debt Capitalization Ratio)**:
# $$
# \text{Debt Capitalization Ratio} = \frac{\text{Общий долг}}{\text{Общий долг} + \text{Собственный капитал}}
# $$
# Этот коэффициент показывает, какая часть капитализации компании приходится на долг. Он помогает оценить, в какой степени компания зависит от долга для финансирования своей деятельности.

# %%
# Расчет финансовых показателей
date = pd.to_datetime(fund_data['date'],format='%Y%m%d')

tic = fund_data['tic'].to_frame('tic')

# Показатели рентабельности
# Операционная маржа (OPM)
OPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='OPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        OPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        OPM.iloc[i] = np.nan
    else:
        OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Чистая операционная маржа (NPM)
NPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='NPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        NPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        NPM.iloc[i] = np.nan
    else:
        NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Рентабельность активов (ROA)
ROA = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROA')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROA[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROA.iloc[i] = np.nan
    else:
        ROA.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['tot_assets'].iloc[i]

# Рентабельность собственного капитала (ROE)
ROE = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROE')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROE[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROE.iloc[i] = np.nan
    else:
        ROE.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['sh_equity'].iloc[i]        

# Для расчета коэффициентов оценки в следующем подразделе предварительно рассчитайте показатели на одну акцию
# Прибыль на акцию (EPS)
EPS = fund_data['eps_incl_ex'].to_frame('EPS')

# Собственный капитал на акцию (Book Value Per Share)
BPS = (fund_data['com_eq']/fund_data['sh_outstanding']).to_frame('BPS') # Need to check units

# Дивиденды на акцию (Dividends Per Share)
DPS = fund_data['div_per_sh'].to_frame('DPS')

# Коэффициенты ликвидности
# Коэффициент текущей ликвидности (Current Ratio)
cur_ratio = (fund_data['cur_assets']/fund_data['cur_liabilities']).to_frame('cur_ratio')

# Быстрый коэффициент ликвидности (Quick Ratio)
quick_ratio = ((fund_data['cash_eq'] + fund_data['receivables'] )/fund_data['cur_liabilities']).to_frame('quick_ratio')

# Коэффициент денежной ликвидности (Cash Ratio)
cash_ratio = (fund_data['cash_eq']/fund_data['cur_liabilities']).to_frame('cash_ratio')


# Коэффициенты эффективности
# Коэффициент оборачиваемости запасов (Inventory Turnover Ratio)
inv_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='inv_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        inv_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        inv_turnover.iloc[i] = np.nan
    else:
        inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]

# Коэффициент оборачиваемости дебиторской задолженности (Receivables Turnover Ratio)    
acc_rec_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_rec_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_rec_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_rec_turnover.iloc[i] = np.nan
    else:
        acc_rec_turnover.iloc[i] = np.sum(fund_data['rev_q'].iloc[i-3:i])/fund_data['receivables'].iloc[i]

# Коэффициент оборачиваемости кредиторской задолженности (Payable Turnover Ratio)
acc_pay_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_pay_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_pay_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_pay_turnover.iloc[i] = np.nan
    else:
        acc_pay_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['payables'].iloc[i]
        
## Коэффициенты кредитного плеча (Leverage Financial Ratios)
# Коэффициент капитализации долга (Debt Capitalization Ratio)
debt_ratio = (fund_data['tot_liabilities']/fund_data['tot_assets']).to_frame('debt_ratio')

# Коэффициент финансового плеча (Debt-to-Equity Ratio)
debt_to_equity = (fund_data['tot_liabilities']/fund_data['sh_equity']).to_frame('debt_to_equity')

# %%
# Соберем датафрейм со всеми рассчитанными показателями
ratios = pd.concat([date,tic,OPM,NPM,ROA,ROE,EPS,BPS,DPS,
                    cur_ratio,quick_ratio,cash_ratio,inv_turnover,acc_rec_turnover,acc_pay_turnover,
                   debt_ratio,debt_to_equity], axis=1)

# %%
# Check the ratio data
ratios.head()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP       NaN       NaN       NaN       NaN  2.73  21.741648
# 1 1999-09-30  AXP       NaN       NaN       NaN       NaN  4.18  21.769437
# 2 1999-12-31  AXP       NaN       NaN       NaN       NaN  5.54  22.588946
# 3 2000-03-31  AXP  0.154281  0.110742  0.012611  0.185312  1.48  23.055993
# 4 2000-06-30  AXP  0.151641  0.108436  0.012857  0.181749  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio inv_turnover acc_rec_turnover  \
# 0  0.225        NaN          NaN         NaN          NaN              NaN
# 1  0.225        NaN          NaN         NaN          NaN              NaN
# 2  0.225        NaN          NaN         NaN          NaN              NaN
# 3  0.225        NaN          NaN         NaN    46.063492         0.319717
# 4  0.080        NaN          NaN         NaN    57.252874         0.324467
#
#   acc_pay_turnover  debt_ratio  debt_to_equity
# 0              NaN    0.926298       12.568121
# 1              NaN    0.926525       12.610016
# 2              NaN    0.932028       13.711937
# 3         0.550059    0.931947       13.694431
# 4         0.505925    0.929258       13.135788

# %%
ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.667517  0.521213  0.129058  0.271736  2.85  13.647142
# 2452 2020-06-30   V  0.668385  0.519867  0.120448  0.264075  3.92  14.203947
# 2453 2020-09-30   V  0.654464   0.52129  0.107873  0.241066  4.90  14.653484
# 2454 2020-12-31   V  0.638994  0.480876  0.094422  0.201545  1.42  15.908283
# 2455 2021-03-31   V  0.640128  0.488704  0.095218  0.202568  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio inv_turnover acc_rec_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150          inf          6.11635
# 2452  0.30   1.553478     1.443292    1.221925          inf         5.063131
# 2453  0.30   1.905238     1.784838    1.579807          inf         5.628571
# 2454  0.32   2.121065     1.969814    1.700081          inf         4.725314
# 2455  0.32   2.116356     1.954292    1.700574          inf         4.844961
#
#      acc_pay_turnover  debt_ratio  debt_to_equity
# 2451         2.697537    0.525062        1.105537
# 2452         1.889507    0.543886        1.192433
# 2453         2.730366    0.552515        1.234714
# 2454         2.347866    0.531507        1.134505
# 2455         2.367357    0.529946        1.127414

# %% [markdown]
# ## 4.4 Обработка пропусков
# Заменим пропуски и NA на ноль.

# %%
# Replace NAs infinite values with zero
final_ratios = ratios.copy()
final_ratios = final_ratios.fillna(0)
final_ratios = final_ratios.replace(np.inf,0)

# %%
final_ratios.head()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP  0.000000  0.000000  0.000000  0.000000  2.73  21.741648
# 1 1999-09-30  AXP  0.000000  0.000000  0.000000  0.000000  4.18  21.769437
# 2 1999-12-31  AXP  0.000000  0.000000  0.000000  0.000000  5.54  22.588946
# 3 2000-03-31  AXP  0.154281  0.110742  0.012611  0.185312  1.48  23.055993
# 4 2000-06-30  AXP  0.151641  0.108436  0.012857  0.181749  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  acc_rec_turnover  \
# 0  0.225        0.0          0.0         0.0      0.000000          0.000000
# 1  0.225        0.0          0.0         0.0      0.000000          0.000000
# 2  0.225        0.0          0.0         0.0      0.000000          0.000000
# 3  0.225        0.0          0.0         0.0     46.063492          0.319717
# 4  0.080        0.0          0.0         0.0     57.252874          0.324467
#
#    acc_pay_turnover  debt_ratio  debt_to_equity
# 0          0.000000    0.926298       12.568121
# 1          0.000000    0.926525       12.610016
# 2          0.000000    0.932028       13.711937
# 3          0.550059    0.931947       13.694431
# 4          0.505925    0.929258       13.135788

# %%
final_ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.667517  0.521213  0.129058  0.271736  2.85  13.647142
# 2452 2020-06-30   V  0.668385  0.519867  0.120448  0.264075  3.92  14.203947
# 2453 2020-09-30   V  0.654464  0.521290  0.107873  0.241066  4.90  14.653484
# 2454 2020-12-31   V  0.638994  0.480876  0.094422  0.201545  1.42  15.908283
# 2455 2021-03-31   V  0.640128  0.488704  0.095218  0.202568  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150           0.0
# 2452  0.30   1.553478     1.443292    1.221925           0.0
# 2453  0.30   1.905238     1.784838    1.579807           0.0
# 2454  0.32   2.121065     1.969814    1.700081           0.0
# 2455  0.32   2.116356     1.954292    1.700574           0.0
#
#       acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity
# 2451          6.116350          2.697537    0.525062        1.105537
# 2452          5.063131          1.889507    0.543886        1.192433
# 2453          5.628571          2.730366    0.552515        1.234714
# 2454          4.725314          2.347866    0.531507        1.134505
# 2455          4.844961          2.367357    0.529946        1.127414

# %% [markdown]
# ## 4.5 Соберем все вместе с ценами в итоговый датасет для моделирования
# - Объединим DataFrame с ценами, предварительно обработанный в части 3, и DataFrame с коэффициентами, созданный в этой части.
# - Поскольку цены представлены ежедневно, а коэффициенты - квартально, после объединения двух DataFrame в столбцах с коэффициентами будут пропущенные значения. Мы решаем эту проблему, заполняя пропущенные значения последним известным значением коэффициента.

# %%
list_ticker = df["tic"].unique().tolist()
list_date = list(pd.date_range(df['date'].min(),df['date'].max()))
combination = list(itertools.product(list_date,list_ticker))

# Merge stock price data and ratios into one dataframe
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(df,on=["date","tic"],how="left")
processed_full = processed_full.merge(final_ratios,how='left',on=['date','tic'])
processed_full = processed_full.sort_values(['tic','date'])

# Backfill the ratio data to make them daily
processed_full = processed_full.bfill(axis='rows')

# %% [markdown]
# ## 4.6 Рассчитать рыночные оценочные коэффициенты, используя ежедневные данные о ценах на акции.

# %%
# Рассчитайте коэффициенты P/E (цена/прибыль), P/B (цена/балансовая стоимость) и дивидендную доходность с использованием ежедневной цены закрытия.
processed_full['PE'] = processed_full['close']/processed_full['EPS']
processed_full['PB'] = processed_full['close']/processed_full['BPS']
processed_full['Div_yield'] = processed_full['DPS']/processed_full['close']

# Удалим показатели на одну акцию, использованные для расчета коэффициентов.
processed_full = processed_full.drop(columns=['day','EPS','BPS','DPS'])

# Заменить пропуски нулями
processed_full = processed_full.copy()
processed_full = processed_full.fillna(0)
processed_full = processed_full.replace(np.inf,0)

# %%
# посмотрим на финальный датасет для моделирования
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#         date   tic      close       high        low       open       volume  \
# 0 2009-01-02  AAPL   2.721687   2.730385   2.554038   2.575631  746015200.0
# 1 2009-01-02  AMGN  40.176655  40.237952  39.332120  39.904224    6547900.0
# 2 2009-01-02   AXP  14.821137  14.966819  14.108066  14.238413   10955700.0
# 3 2009-01-02    BA  33.941101  34.173627  32.088404  32.103406    7010200.0
# 4 2009-01-02   CAT  30.076941  30.121822  28.666382  28.794615    7117200.0
# 5 2009-01-02   CRM   8.402903   8.447362   7.817515   7.928664    4069200.0
# 6 2009-01-02  CSCO  10.973992  10.999875  10.514586  10.618115   40980600.0
# 7 2009-01-02   CVX  38.845619  39.241592  37.353122  37.683097   13695900.0
# 8 2009-01-02   DIS  20.123596  20.216138  18.928968  19.147703    9796600.0
# 9 2009-01-02   DOW  34.132931  36.668912  33.927311  36.154862    2350800.0
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 1  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 2  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 3  0.047307  0.032525  0.026400  ...     0.368463    0.148507      2.329670
# 4  0.124545  0.066662  0.040891  ...     0.890488    0.163158      3.540791
# 5  0.234698  0.196418  0.097593  ...     2.498162    2.170759      9.054201
# 6  0.234698  0.196418  0.097593  ...     2.498162    2.170759      9.054201
# 7  0.141417  0.097223  0.117691  ...     0.952878    0.373760     23.920348
# 8  0.167221  0.102157  0.045834  ...     0.815629    0.330748     11.310223
# 9  0.000000  0.000000  0.000000  ...     0.000000    0.000000      0.000000
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity          PE  \
# 0          8.972003          4.269115    0.437727        0.778495    0.625675
# 1          0.351354          0.653355    0.869784        6.679531  129.602112
# 2          0.351354          0.653355    0.869784        6.679531   47.810121
# 3          6.815203          2.076967    1.009198     -109.722986   39.012760
# 4          2.460351          8.472455    0.893715        9.089489 -158.299687
# 5          6.844634         16.036800    0.400215        0.667591   13.337941
# 6          6.844634         16.036800    0.400215        0.667591   17.419035
# 7         13.387209         11.276861    0.449174        0.815455   42.223499
# 8          5.725855          4.287167    0.455848        0.837721   25.472907
# 9          0.000000          0.000000    0.000000        0.000000  148.404047
#
#           PB  Div_yield
# 0   0.099852   0.000000
# 1   3.720769   0.004480
# 2   1.372589   0.012145
# 3 -35.751054   0.012374
# 4   2.903047   0.013964
# 5   1.335034   0.000000
# 6   1.743523   0.000000
# 7   0.891880   0.016733
# 8   1.100592   0.017393
# 9   0.000000   0.000000
#
# [10 rows x 22 columns]

# %% [markdown]
# <a id='4'></a>
# # Часть 5. Модель рынка
# Процесс обучения включает наблюдение за изменением цен на акции, принятие решения и расчет вознаграждения. Взаимодействуя с рыночной средой, агент в конечном итоге разработает торговую стратегию, которая поможет ему максимизировать (ожидаемые) вознаграждения.
#
# Модель рыночной среды, основанная на OpenAI Gym, моделирует фондовые рынки на исторических рыночных данных.

# %% [markdown]
# ## 5.1 Разделим данные на train и test (trade)
# - Training data period: 2009-01-01 to 2019-01-01
# - Trade data period: 2019-01-01 to 2020-12-31

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 105879
# 21199

# %%
train_data.head()
# Out:
#         date   tic      close       high        low       open       volume  \
# 0 2009-01-02  AAPL   2.721687   2.730385   2.554038   2.575631  746015200.0
# 0 2009-01-02  AMGN  40.176655  40.237952  39.332120  39.904224    6547900.0
# 0 2009-01-02   AXP  14.821137  14.966819  14.108066  14.238413   10955700.0
# 0 2009-01-02    BA  33.941101  34.173627  32.088404  32.103406    7010200.0
# 0 2009-01-02   CAT  30.076941  30.121822  28.666382  28.794615    7117200.0
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 0  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 0  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 0  0.047307  0.032525  0.026400  ...     0.368463    0.148507      2.329670
# 0  0.124545  0.066662  0.040891  ...     0.890488    0.163158      3.540791
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity          PE  \
# 0          8.972003          4.269115    0.437727        0.778495    0.625675
# 0          0.351354          0.653355    0.869784        6.679531  129.602112
# 0          0.351354          0.653355    0.869784        6.679531   47.810121
# 0          6.815203          2.076967    1.009198     -109.722986   39.012760
# 0          2.460351          8.472455    0.893715        9.089489 -158.299687
#
#           PB  Div_yield
# 0   0.099852   0.000000
# 0   3.720769   0.004480
# 0   1.372589   0.012145
# 0 -35.751054   0.012374
# 0   2.903047   0.013964
#
# [5 rows x 22 columns]

# %%
trade_data.head()
# Out:
#         date   tic       close        high         low        open  \
# 0 2019-01-01  AAPL   37.538826   37.759896   36.661683   36.818571
# 0 2019-01-01  AMGN  154.827866  155.876728  152.447763  155.328100
# 0 2019-01-01   AXP   86.900307   87.436164   85.165567   85.292727
# 0 2019-01-01    BA  314.645142  314.781193  304.830998  307.240817
# 0 2019-01-01   CAT  108.229256  109.513825  105.334695  106.216765
#
#         volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0  148158800.0  0.258891  0.227773  0.133360  ...     1.134347    0.854114
# 0    3009100.0  0.093973  0.072040  0.014094  ...     0.000000    0.000000
# 0    4175400.0  0.203479  0.160494  0.026811  ...     0.000000    0.000000
# 0    3292200.0  0.116496  0.102682  0.066409  ...     0.262465    0.092436
# 0    4783200.0  0.186871  0.107064  0.056932  ...     0.919490    0.266175
#
#    inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0     23.571867          7.620024          3.781658    0.690466
# 0      0.000000          0.351354          0.653355    0.869784
# 0      0.000000          0.231669          0.279424    0.887329
# 0      0.933164          5.468453          4.151637    0.998070
# 0      2.135008          2.339630          3.660183    0.803394
#
#    debt_to_equity          PE           PB  Div_yield
# 0        2.230663    5.602810     1.633781   0.019447
# 0        6.679531  499.444728    14.338642   0.001163
# 0        7.875371   48.011219     3.273722   0.004488
# 0      517.142241   83.019826  1418.196271   0.006531
# 0        4.086316   32.896430     4.008219   0.007946
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 5.2 Построим модель рынка

# %%
import gymnasium as gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gymnasium import spaces
from gymnasium.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

# matplotlib.use("Agg")

# from stable_baselines3.common import logger

# %%
gym.__version__
# Out:
# '1.2.3'

# %%
class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        turbulence_threshold=None,
        risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        self.day = day
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        self.turbulence_threshold = turbulence_threshold
        self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        # self._seed()

    def _sell_stock(self, index, action):
        def _do_sell_normal():
            if self.state[index + 1] > 0:
                # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.state[index + self.stock_dim + 1] > 0:
                    # Sell only if current asset is > 0
                    sell_num_shares = min(
                        abs(action), self.state[index + self.stock_dim + 1]
                    )
                    sell_amount = (
                        self.state[index + 1]
                        * sell_num_shares
                        * (1 - self.sell_cost_pct)
                    )
                    # update balance
                    self.state[0] += sell_amount

                    self.state[index + self.stock_dim + 1] -= sell_num_shares
                    self.cost += (
                        self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                    )
                    self.trades += 1
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = 0

            return sell_num_shares

        # perform sell action based on the sign of the action
        if self.turbulence_threshold is not None:
            if self.turbulence >= self.turbulence_threshold:
                if self.state[index + 1] > 0:
                    # Sell only if the price is > 0 (no missing data in this particular date)
                    # if turbulence goes over threshold, just clear out all positions
                    if self.state[index + self.stock_dim + 1] > 0:
                        # Sell only if current asset is > 0
                        sell_num_shares = self.state[index + self.stock_dim + 1]
                        sell_amount = (
                            self.state[index + 1]
                            * sell_num_shares
                            * (1 - self.sell_cost_pct)
                        )
                        # update balance
                        self.state[0] += sell_amount
                        self.state[index + self.stock_dim + 1] = 0
                        self.cost += (
                            self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                        )
                        self.trades += 1
                    else:
                        sell_num_shares = 0
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = _do_sell_normal()
        else:
            sell_num_shares = _do_sell_normal()

        return sell_num_shares

    def _buy_stock(self, index, action):
        def _do_buy():
            if self.state[index + 1] > 0:
                # Buy only if the price is > 0 (no missing data in this particular date)
                available_amount = self.state[0] // self.state[index + 1]
                # print('available_amount:{}'.format(available_amount))

                # update balance
                buy_num_shares = min(available_amount, action)
                buy_amount = (
                    self.state[index + 1] * buy_num_shares * (1 + self.buy_cost_pct)
                )
                self.state[0] -= buy_amount

                self.state[index + self.stock_dim + 1] += buy_num_shares

                self.cost += self.state[index + 1] * buy_num_shares * self.buy_cost_pct
                self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        # perform buy action based on the sign of the action
        if self.turbulence_threshold is None:
            buy_num_shares = _do_buy()
        else:
            if self.turbulence < self.turbulence_threshold:
                buy_num_shares = _do_buy()
            else:
                buy_num_shares = 0
                pass

        return buy_num_shares

    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        truncated = False
        info = {}
        if self.terminal:
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = (
                self.state[0]
                + sum(
                    np.array(self.state[1 : (self.stock_dim + 1)])
                    * np.array(
                        self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                    )
                )
                - self.initial_amount
            )
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(
                1
            )
            if df_total_value["daily_return"].std() != 0:
                sharpe = (
                    (252 ** 0.5)
                    * df_total_value["daily_return"].mean()
                    / df_total_value["daily_return"].std()
                )
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}") 
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            # Add outputs to logger interface
            # logger.record("environment/portfolio_value", end_total_asset)
            # logger.record("environment/total_reward", tot_reward)
            # logger.record("environment/total_reward_pct", (tot_reward / (end_total_asset - tot_reward)) * 100)
            # logger.record("environment/total_cost", self.cost)
            # logger.record("environment/total_trades", self.trades)

            # return self.state, self.reward, self.terminal, {}
            # можно полезные метрики положить в info
            info["end_total_asset"] = float(end_total_asset)
            info["cost"] = float(self.cost)
            info["trades"] = int(self.trades)
            return np.array(self.state, dtype=np.float32), float(self.reward), self.terminal, truncated, info

        else:

            actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            actions = actions.astype(
                int
            )  # convert into integer because we can't by fraction of shares
            if self.turbulence_threshold is not None:
                if self.turbulence >= self.turbulence_threshold:
                    actions = np.array([-self.hmax] * self.stock_dim)
            begin_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            # print("begin_total_asset:{}".format(begin_total_asset))

            argsort_actions = np.argsort(actions)

            sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][: np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print(f"Num shares before: {self.state[index+self.stock_dim+1]}")
                # print(f'take sell action before : {actions[index]}')
                actions[index] = self._sell_stock(index, actions[index]) * (-1)
                # print(f'take sell action after : {actions[index]}')
                # print(f"Num shares after: {self.state[index+self.stock_dim+1]}")

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                actions[index] = self._buy_stock(index, actions[index])

            self.actions_memory.append(actions)

            # state: s -> s+1
            self.day += 1
            self.data = self.df.loc[self.day, :]
            if self.turbulence_threshold is not None:
                if len(self.df.tic.unique()) == 1:
                    self.turbulence = self.data[self.risk_indicator_col]
                elif len(self.df.tic.unique()) > 1:
                    self.turbulence = self.data[self.risk_indicator_col].values[0]
            self.state = self._update_state()

            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        # return self.state, self.reward, self.terminal, {}
        return np.array(self.state, dtype=np.float32), float(self.reward), self.terminal, truncated, info

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed) 
        # initiate state
        self.state = self._initiate_state()

        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = self.previous_state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(
                    self.previous_state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                )
            )
            self.asset_memory = [previous_total_asset]

        self.day = 0
        self.data = self.df.loc[self.day, :]
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        # self.iteration=self.iteration
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        info = {}
        return np.array(self.state, dtype=np.float32), info

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        if self.initial:
            # For Initial State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.initial_amount]
                    + self.data.close.values.tolist()
                    + [0] * self.stock_dim
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.initial_amount]
                    + [self.data.close]
                    + [0] * self.stock_dim
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        else:
            # Using Previous State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.previous_state[0]]
                    + self.data.close.values.tolist()
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.previous_state[0]]
                    + [self.data.close]
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        return state

    def _update_state(self):
        if len(self.df.tic.unique()) > 1:
            # for multiple stock
            state = (
                [self.state[0]]
                + self.data.close.values.tolist()
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(
                    [
                        self.data[tech].values.tolist()
                        for tech in self.tech_indicator_list
                    ],
                    [],
                )
            )

        else:
            # for single stock
            state = (
                [self.state[0]]
                + [self.data.close]
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
            )
        return state

    def _get_date(self):
        if len(self.df.tic.unique()) > 1:
            date = self.data.date.unique()[0]
        else:
            date = self.data.date
        return date

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            action_list = self.actions_memory
            df_actions = pd.DataFrame(action_list)
            df_actions.columns = self.data.tic.values
            df_actions.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            action_list = self.actions_memory
            df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    # def _seed(self, seed=None):
    #     self.np_random, seed = seeding.np_random(seed)
    #     return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
ratio_list = ['OPM', 'NPM','ROA', 'ROE', 'cur_ratio', 'quick_ratio', 'cash_ratio', 'inv_turnover','acc_rec_turnover', 'acc_pay_turnover', 'debt_ratio', 'debt_to_equity',
       'PE', 'PB', 'Div_yield']

stock_dimension = len(train_data.tic.unique())
state_space = 1 + 2*stock_dimension + len(ratio_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 494

# %%
# Параметры среды (модели рынка)
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": ratio_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %% [markdown]
# ## Создаем экземпляр окружения для тренировки модели

# %%
env_train, _ = e_train_gym.get_sb_env()
# print(type(env_train))

# %% [markdown]
# <a id='5'></a>
# # Часть 6: Тренировка агента
# * Алгоритмы DRL взяты из **Stable Baselines 3**. Так же можно использовать `ElegantRL` и `Ray RLlib`.
# * Библиотека FinRL включает настроенные стандартные алгоритмы DRL, такие как DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C и TD3. Мы также позволяем пользователям создавать свои собственные алгоритмы DRL, адаптируя эти алгоритмы DRL.

# %%
# Set up the agent using DRLAgent() class using the environment created in the previous part
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Обучим агента: 5 алгоритмов (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Model 1: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
if exists('./trained_models/trained_ppo.model'):
    trained_ppo = model_ppo.load('./trained_models/trained_ppo.model')
else:
    trained_ppo = agent.train_model(model=model_ppo, 
                            tb_log_name='ppo',
                            total_timesteps=50000) if if_using_ppo else None

    trained_ppo.save('./trained_models/trained_ppo.model')
# Out:
# ------------------------------------
# | time/              |             |
# |    fps             | 151         |
# |    iterations      | 1           |
# |    time_elapsed    | 13          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.32959303 |
# |    reward_max      | 5.9784975   |
# |    reward_mean     | 0.05923084  |
# |    reward_min      | -8.461383   |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 2           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016111681 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00201     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.024      |
# |    reward               | 1.2574195   |
# |    reward_max           | 18.99592    |
# |    reward_mean          | 0.09764559  |
# |    reward_min           | -18.925997  |
# |    std                  | 1           |
# |    value_loss           | 7.98        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 3           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014393754 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00799     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0185     |
# |    reward               | 2.0900455   |
# |    reward_max           | 7.803132    |
# |    reward_mean          | 0.054761264 |
# |    reward_min           | -7.576254   |
# |    std                  | 1           |
# |    value_loss           | 35.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 4           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015076107 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0121     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.09        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0208     |
# |    reward               | -0.12311215 |
# |    reward_max           | 19.387909   |
# |    reward_mean          | 0.08677213  |
# |    reward_min           | -18.374697  |
# |    std                  | 1.01        |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 5           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016983898 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.004       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0185     |
# |    reward               | 0.1526086   |
# |    reward_max           | 6.4438133   |
# |    reward_mean          | 0.037393644 |
# |    reward_min           | -9.07931    |
# |    std                  | 1.01        |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 6           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015820576 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.00642     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.1         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0258     |
# |    reward               | 0.1415157   |
# |    reward_max           | 12.219897   |
# |    reward_mean          | 0.0420451   |
# |    reward_min           | -12.823747  |
# |    std                  | 1.01        |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 7            |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.016227927  |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.5        |
# |    explained_variance   | 0.0438       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0218      |
# |    reward               | -0.016118146 |
# |    reward_max           | 8.835353     |
# |    reward_mean          | 0.07121544   |
# |    reward_min           | -13.114533   |
# |    std                  | 1.01         |
# |    value_loss           | 22           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 8            |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.017720057  |
# |    clip_fraction        | 0.178        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.6        |
# |    explained_variance   | -0.00962     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.02         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0154      |
# |    reward               | -0.008659791 |
# |    reward_max           | 13.460568    |
# |    reward_mean          | 0.038193367  |
# |    reward_min           | -12.343952   |
# |    std                  | 1.02         |
# |    value_loss           | 19.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 9            |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.021556133  |
# |    clip_fraction        | 0.264        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.7        |
# |    explained_variance   | -0.00277     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0194      |
# |    reward               | -0.004198902 |
# |    reward_max           | 12.666598    |
# |    reward_mean          | 0.043452922  |
# |    reward_min           | -14.920039   |
# |    std                  | 1.02         |
# |    value_loss           | 15.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 10          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018211521 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0191      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.33        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | 2.591739    |
# |    reward_max           | 6.531995    |
# |    reward_mean          | 0.06169297  |
# |    reward_min           | -7.0005965  |
# |    std                  | 1.02        |
# |    value_loss           | 22.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 11          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015152218 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.0129     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.23        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0166     |
# |    reward               | 0.22245842  |
# |    reward_max           | 12.487158   |
# |    reward_mean          | 0.040045075 |
# |    reward_min           | -16.681662  |
# |    std                  | 1.02        |
# |    value_loss           | 9.69        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 12           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.027007421  |
# |    clip_fraction        | 0.271        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | -0.00265     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0149      |
# |    reward               | -0.013339995 |
# |    reward_max           | 7.350227     |
# |    reward_mean          | 0.053797256  |
# |    reward_min           | -7.686065    |
# |    std                  | 1.03         |
# |    value_loss           | 25.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 13           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0157166    |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | -0.0352      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.02         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0154      |
# |    reward               | -0.006273493 |
# |    reward_max           | 11.599371    |
# |    reward_mean          | 0.038226444  |
# |    reward_min           | -17.532785   |
# |    std                  | 1.03         |
# |    value_loss           | 14.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 14          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.036026247 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.0176     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.4        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | 1.0188432   |
# |    reward_max           | 6.657461    |
# |    reward_mean          | 0.066333316 |
# |    reward_min           | -7.493681   |
# |    std                  | 1.03        |
# |    value_loss           | 22.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 15          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020664781 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0176      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.91        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | 1.4647855   |
# |    reward_max           | 11.440475   |
# |    reward_mean          | 0.03332259  |
# |    reward_min           | -15.458343  |
# |    std                  | 1.03        |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 145        |
# |    iterations           | 16         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02680954 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.1      |
# |    explained_variance   | -0.0157    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.3        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0177    |
# |    reward               | 3.5135326  |
# |    reward_max           | 10.914917  |
# |    reward_mean          | 0.09016163 |
# |    reward_min           | -18.834595 |
# |    std                  | 1.03       |
# |    value_loss           | 17         |
# ----------------------------------------
# day: 3650, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3147746.80
# total_reward: 2147746.80
# total_cost: 316719.03
# total_trades: 98750
# Sharpe: 0.692
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 17          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017564839 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -0.00771    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.79        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | -0.08234592 |
# |    reward_max           | 13.236801   |
# |    reward_mean          | 0.03836416  |
# |    reward_min           | -11.635106  |
# |    std                  | 1.04        |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 18          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024821816 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0073      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.59        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.018      |
# |    reward               | 0.5732925   |
# |    reward_max           | 12.280111   |
# |    reward_mean          | 0.057006594 |
# |    reward_min           | -17.875647  |
# |    std                  | 1.04        |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 19          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014261224 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0489      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.79        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.019      |
# |    reward               | -1.7419151  |
# |    reward_max           | 6.377008    |
# |    reward_mean          | 0.03514691  |
# |    reward_min           | -6.8341236  |
# |    std                  | 1.04        |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 20          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.030381538 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | -0.0586     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.86        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0185     |
# |    reward               | -0.76847285 |
# |    reward_max           | 11.119362   |
# |    reward_mean          | 0.05547123  |
# |    reward_min           | -13.351124  |
# |    std                  | 1.04        |
# |    value_loss           | 8.96        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 21          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023581143 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.0449     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.2         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | 1.6443621   |
# |    reward_max           | 15.946156   |
# |    reward_mean          | 0.10330104  |
# |    reward_min           | -13.295449  |
# |    std                  | 1.04        |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 22          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025828121 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.0407     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.2         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0153     |
# |    reward               | -2.1036334  |
# |    reward_max           | 27.661371   |
# |    reward_mean          | 0.13830647  |
# |    reward_min           | -27.889967  |
# |    std                  | 1.05        |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 23           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.026132293  |
# |    clip_fraction        | 0.288        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.5        |
# |    explained_variance   | -0.0182      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 35.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0117      |
# |    reward               | -0.016104834 |
# |    reward_max           | 6.780322     |
# |    reward_mean          | 0.0818472    |
# |    reward_min           | -8.120769    |
# |    std                  | 1.05         |
# |    value_loss           | 67.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 24          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.02103677  |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -0.00952    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.21        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0125     |
# |    reward               | -0.00731181 |
# |    reward_max           | 12.799397   |
# |    reward_mean          | 0.0444067   |
# |    reward_min           | -14.299126  |
# |    std                  | 1.05        |
# |    value_loss           | 12          |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 145           |
# |    iterations           | 25            |
# |    time_elapsed         | 351           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.030106014   |
# |    clip_fraction        | 0.311         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | 0.0453        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.59          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.0197       |
# |    reward               | -0.0029024938 |
# |    reward_max           | 24.073757     |
# |    reward_mean          | 0.16662677    |
# |    reward_min           | -26.916336    |
# |    std                  | 1.05          |
# |    value_loss           | 16            |
# -------------------------------------------

# %% [markdown]
# ### Model 2: DDPG

# %%
tmp_path = RESULTS_DIR + "/ddpg"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model_ddpg = agent.get_model("ddpg")
model_ddpg.set_logger(new_logger)

if exists('./trained_models/trained_ddpg.model'):
    trained_ddpg = model_ddpg.load('./trained_models/trained_ddpg.model')
else:
    if if_using_ddpg:
        # ВАЖНО: callback=None, чтобы FinRL-коллбэки не лезли в rollout_buffer
        model_ddpg.learn(
            total_timesteps=50_000,
            tb_log_name="ddpg",
            callback=None,
        )
        trained_ddpg = model_ddpg 

        trained_ddpg.save('./trained_models/trained_ddpg.model')
# Out:
# Logging to results/ddpg
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# day: 3650, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4724803.41
# total_reward: 3724803.41
# total_cost: 999.00
# total_trades: 61994
# Sharpe: 0.810
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 59       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 14604    |
# | train/             |          |
# |    actor_loss      | -9.21    |
# |    critic_loss     | 7.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14503    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 59       |
# |    time_elapsed    | 494      |
# |    total_timesteps | 29208    |
# | train/             |          |
# |    actor_loss      | -9.35    |
# |    critic_loss     | 6        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29107    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 58       |
# |    time_elapsed    | 753      |
# |    total_timesteps | 43812    |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 2.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43711    |
# ---------------------------------

# %% [markdown]
# ### Model 3: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
if exists('./trained_models/trained_a2c.model'):
    trained_a2c = model_a2c.load('./trained_models/trained_a2c.model')
else:
    trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

    trained_a2c.save('./trained_models/trained_a2c.model')
# Out:
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 100           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -41.3         |
# |    explained_variance | 0.0532        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | 77.9          |
# |    reward             | -0.0029777803 |
# |    reward_max         | 0.1025663     |
# |    reward_mean        | -0.7544105    |
# |    reward_min         | -1.9803624    |
# |    std                | 1             |
# |    value_loss         | 6.07          |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 134          |
# |    iterations         | 200          |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -41.3        |
# |    explained_variance | 0.0693       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 27.2         |
# |    reward             | 0.9705455    |
# |    reward_max         | 0.97722554   |
# |    reward_mean        | -0.120058194 |
# |    reward_min         | -2.5421505   |
# |    std                | 1.01         |
# |    value_loss         | 8.57         |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 134            |
# |    iterations         | 300            |
# |    time_elapsed       | 11             |
# |    total_timesteps    | 1500           |
# | train/                |                |
# |    entropy_loss       | -41.4          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 299            |
# |    policy_loss        | 109            |
# |    reward             | -0.00012222228 |
# |    reward_max         | 1.1490248      |
# |    reward_mean        | 0.016817624    |
# |    reward_min         | -0.86072475    |
# |    std                | 1.01           |
# |    value_loss         | 6.93           |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 400         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 92.6        |
# |    reward             | 1.580731    |
# |    reward_max         | 1.580731    |
# |    reward_mean        | 0.22097594  |
# |    reward_min         | -0.92438954 |
# |    std                | 1.01        |
# |    value_loss         | 5.04        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 500         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 17.5        |
# |    reward             | -3.546493   |
# |    reward_max         | 1.5187546   |
# |    reward_mean        | -0.22124685 |
# |    reward_min         | -3.546493   |
# |    std                | 1.01        |
# |    value_loss         | 2.71        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 135           |
# |    iterations         | 600           |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -41.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -3.21         |
# |    reward             | -4.6915283    |
# |    reward_max         | -0.0045957626 |
# |    reward_mean        | -1.0234945    |
# |    reward_min         | -4.6915283    |
# |    std                | 1.01          |
# |    value_loss         | 0.0329        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 136           |
# |    iterations         | 700           |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -41.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -525          |
# |    reward             | 1.5436856     |
# |    reward_max         | 3.6809418     |
# |    reward_mean        | 1.9748671     |
# |    reward_min         | -0.0029520667 |
# |    std                | 1.01          |
# |    value_loss         | 276           |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 136           |
# |    iterations         | 800           |
# |    time_elapsed       | 29            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -41.6         |
# |    explained_variance | -3.1e-06      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 52.5          |
# |    reward             | -1.9166535    |
# |    reward_max         | -0.0008522186 |
# |    reward_mean        | -0.80474085   |
# |    reward_min         | -1.9166535    |
# |    std                | 1.01          |
# |    value_loss         | 1.62          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 136           |
# |    iterations         | 900           |
# |    time_elapsed       | 32            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -41.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 102           |
# |    reward             | -0.0014330765 |
# |    reward_max         | 0.84159285    |
# |    reward_mean        | 0.29197478    |
# |    reward_min         | -0.33766237   |
# |    std                | 1.02          |
# |    value_loss         | 6.58          |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 137          |
# |    iterations         | 1000         |
# |    time_elapsed       | 36           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | 0.0299       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 80.5         |
# |    reward             | -0.068922445 |
# |    reward_max         | 0.9269509    |
# |    reward_mean        | -0.25015718  |
# |    reward_min         | -2.1012146   |
# |    std                | 1.02         |
# |    value_loss         | 6.68         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1100       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.000424  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -24.2      |
# |    reward             | -1.3644027 |
# |    reward_max         | 0.92106354 |
# |    reward_mean        | -1.1554242 |
# |    reward_min         | -3.111647  |
# |    std                | 1.02       |
# |    value_loss         | 0.815      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1200       |
# |    time_elapsed       | 43         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -28.4      |
# |    reward             | -0.8340355 |
# |    reward_max         | 0.28915372 |
# |    reward_mean        | -0.4975465 |
# |    reward_min         | -1.9358051 |
# |    std                | 1.02       |
# |    value_loss         | 0.518      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1300       |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -43.9      |
# |    reward             | -0.7793225 |
# |    reward_max         | 1.5523604  |
# |    reward_mean        | 0.5904441  |
# |    reward_min         | -0.7793225 |
# |    std                | 1.02       |
# |    value_loss         | 3.26       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 137           |
# |    iterations         | 1400          |
# |    time_elapsed       | 50            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -41.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | -252          |
# |    reward             | -0.0037810472 |
# |    reward_max         | 3.5745156     |
# |    reward_mean        | 0.4250895     |
# |    reward_min         | -1.7144172    |
# |    std                | 1.02          |
# |    value_loss         | 47.6          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 137           |
# |    iterations         | 1500          |
# |    time_elapsed       | 54            |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -41.8         |
# |    explained_variance | 0.177         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1499          |
# |    policy_loss        | 37.6          |
# |    reward             | -0.0028140205 |
# |    reward_max         | 2.8208485     |
# |    reward_mean        | 1.0071093     |
# |    reward_min         | -0.0028140205 |
# |    std                | 1.02          |
# |    value_loss         | 1.43          |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 1600        |
# |    time_elapsed       | 58          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -32.1       |
# |    reward             | 2.7465286   |
# |    reward_max         | 2.7465286   |
# |    reward_mean        | 0.30082613  |
# |    reward_min         | -0.80849123 |
# |    std                | 1.02        |
# |    value_loss         | 1.47        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1700       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -34.1      |
# |    reward             | 1.3123996  |
# |    reward_max         | 1.3123996  |
# |    reward_mean        | -0.4445317 |
# |    reward_min         | -2.2863727 |
# |    std                | 1.02       |
# |    value_loss         | 1.55       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1800       |
# |    time_elapsed       | 65         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 5.27       |
# |    reward             | -0.9778125 |
# |    reward_max         | 0.5625079  |
# |    reward_mean        | -0.2788226 |
# |    reward_min         | -0.9785368 |
# |    std                | 1.02       |
# |    value_loss         | 0.185      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 1900       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -77.4      |
# |    reward             | -3.1397839 |
# |    reward_max         | 5.2722244  |
# |    reward_mean        | 2.0525813  |
# |    reward_min         | -3.1397839 |
# |    std                | 1.03       |
# |    value_loss         | 5.43       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 137           |
# |    iterations         | 2000          |
# |    time_elapsed       | 72            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -41.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | -184          |
# |    reward             | -0.0021920155 |
# |    reward_max         | 8.899131      |
# |    reward_mean        | 1.9019276     |
# |    reward_min         | -1.0678054    |
# |    std                | 1.03          |
# |    value_loss         | 20.8          |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 2100        |
# |    time_elapsed       | 76          |
# |    total_timesteps    | 10500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2099        |
# |    policy_loss        | -59.2       |
# |    reward             | 1.1809767   |
# |    reward_max         | 1.5237545   |
# |    reward_mean        | 0.5088728   |
# |    reward_min         | -0.16026959 |
# |    std                | 1.03        |
# |    value_loss         | 3.17        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 2200        |
# |    time_elapsed       | 80          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | -37         |
# |    reward             | 0.16401275  |
# |    reward_max         | 0.16401275  |
# |    reward_mean        | -0.40625516 |
# |    reward_min         | -2.1842496  |
# |    std                | 1.03        |
# |    value_loss         | 1.49        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 2300        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | -26.1       |
# |    reward             | 0.6612416   |
# |    reward_max         | 0.6612416   |
# |    reward_mean        | -0.77703387 |
# |    reward_min         | -1.9876275  |
# |    std                | 1.03        |
# |    value_loss         | 0.949       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 2400        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2399        |
# |    policy_loss        | -39.3       |
# |    reward             | -2.0327032  |
# |    reward_max         | 2.4358308   |
# |    reward_mean        | -0.15205075 |
# |    reward_min         | -2.0327032  |
# |    std                | 1.03        |
# |    value_loss         | 2.92        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 2500        |
# |    time_elapsed       | 91          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 18.4        |
# |    reward             | 0.2068389   |
# |    reward_max         | 1.0785692   |
# |    reward_mean        | -0.23960048 |
# |    reward_min         | -1.2584273  |
# |    std                | 1.03        |
# |    value_loss         | 0.756       |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 136            |
# |    iterations         | 2600           |
# |    time_elapsed       | 95             |
# |    total_timesteps    | 13000          |
# | train/                |                |
# |    entropy_loss       | -42.1          |
# |    explained_variance | 0.0721         |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 2599           |
# |    policy_loss        | -96.2          |
# |    reward             | -1.3979194e-05 |
# |    reward_max         | 2.8135765      |
# |    reward_mean        | 0.567823       |
# |    reward_min         | -0.39648426    |
# |    std                | 1.03           |
# |    value_loss         | 6.49           |
# ------------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 2700       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -0.142     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -154       |
# |    reward             | -1.6685673 |
# |    reward_max         | 4.0423074  |
# |    reward_mean        | 0.7013456  |
# |    reward_min         | -1.6685673 |
# |    std                | 1.04       |
# |    value_loss         | 21.4       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 135           |
# |    iterations         | 2800          |
# |    time_elapsed       | 102           |
# |    total_timesteps    | 14000         |
# | train/                |               |
# |    entropy_loss       | -42.2         |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2799          |
# |    policy_loss        | 23.5          |
# |    reward             | -0.0008393782 |
# |    reward_max         | 3.4153903     |
# |    reward_mean        | 1.0554885     |
# |    reward_min         | -2.1186843    |
# |    std                | 1.04          |
# |    value_loss         | 1.02          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 2900       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | 84.9       |
# |    reward             | 0.9616953  |
# |    reward_max         | 1.0823513  |
# |    reward_mean        | -0.2375063 |
# |    reward_min         | -3.2268884 |
# |    std                | 1.04       |
# |    value_loss         | 9.2        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 3000        |
# |    time_elapsed       | 110         |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | -75.6       |
# |    reward             | 1.8266507   |
# |    reward_max         | 1.8266507   |
# |    reward_mean        | 0.5723803   |
# |    reward_min         | -0.57123476 |
# |    std                | 1.04        |
# |    value_loss         | 3.45        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 3100        |
# |    time_elapsed       | 114         |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | -54.8       |
# |    reward             | 0.008531321 |
# |    reward_max         | 1.8250717   |
# |    reward_mean        | 0.069942184 |
# |    reward_min         | -2.5787847  |
# |    std                | 1.04        |
# |    value_loss         | 2.71        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 3200       |
# |    time_elapsed       | 118        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -138       |
# |    reward             | 0.0        |
# |    reward_max         | 1.6586616  |
# |    reward_mean        | 0.03795915 |
# |    reward_min         | -1.3314397 |
# |    std                | 1.04       |
# |    value_loss         | 13.7       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 3300        |
# |    time_elapsed       | 122         |
# |    total_timesteps    | 16500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3299        |
# |    policy_loss        | 28.3        |
# |    reward             | -2.0415301  |
# |    reward_max         | 1.4111058   |
# |    reward_mean        | -0.12942079 |
# |    reward_min         | -2.0415301  |
# |    std                | 1.04        |
# |    value_loss         | 0.699       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 3400          |
# |    time_elapsed       | 126           |
# |    total_timesteps    | 17000         |
# | train/                |               |
# |    entropy_loss       | -42.2         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3399          |
# |    policy_loss        | -44.9         |
# |    reward             | -0.0025558267 |
# |    reward_max         | -0.0025558267 |
# |    reward_mean        | -1.2268317    |
# |    reward_min         | -2.4930985    |
# |    std                | 1.04          |
# |    value_loss         | 1.86          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 3500          |
# |    time_elapsed       | 129           |
# |    total_timesteps    | 17500         |
# | train/                |               |
# |    entropy_loss       | -42.2         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3499          |
# |    policy_loss        | -33.4         |
# |    reward             | 3.1058922     |
# |    reward_max         | 3.1058922     |
# |    reward_mean        | 0.89363736    |
# |    reward_min         | -0.0008374745 |
# |    std                | 1.04          |
# |    value_loss         | 0.86          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 3600       |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | 45.8       |
# |    reward             | -1.4403993 |
# |    reward_max         | 2.7898812  |
# |    reward_mean        | -1.5015229 |
# |    reward_min         | -4.5361466 |
# |    std                | 1.04       |
# |    value_loss         | 2.36       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 3700        |
# |    time_elapsed       | 137         |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0.161       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | -32.4       |
# |    reward             | 1.0234483   |
# |    reward_max         | 1.0234483   |
# |    reward_mean        | -0.29699457 |
# |    reward_min         | -2.118925   |
# |    std                | 1.04        |
# |    value_loss         | 0.837       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 3800          |
# |    time_elapsed       | 140           |
# |    total_timesteps    | 19000         |
# | train/                |               |
# |    entropy_loss       | -42.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3799          |
# |    policy_loss        | 37            |
# |    reward             | -0.0022364212 |
# |    reward_max         | 1.1514325     |
# |    reward_mean        | -0.014313428  |
# |    reward_min         | -1.2503324    |
# |    std                | 1.04          |
# |    value_loss         | 0.892         |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 3900        |
# |    time_elapsed       | 144         |
# |    total_timesteps    | 19500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3899        |
# |    policy_loss        | 62          |
# |    reward             | 0.8691103   |
# |    reward_max         | 0.8691103   |
# |    reward_mean        | -0.23161425 |
# |    reward_min         | -2.0266867  |
# |    std                | 1.04        |
# |    value_loss         | 2.16        |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 134            |
# |    iterations         | 4000           |
# |    time_elapsed       | 148            |
# |    total_timesteps    | 20000          |
# | train/                |                |
# |    entropy_loss       | -42.3          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 3999           |
# |    policy_loss        | -90.7          |
# |    reward             | -0.00031335594 |
# |    reward_max         | 3.9499714      |
# |    reward_mean        | 1.110522       |
# |    reward_min         | -0.00031335594 |
# |    std                | 1.04           |
# |    value_loss         | 5.16           |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 134          |
# |    iterations         | 4100         |
# |    time_elapsed       | 152          |
# |    total_timesteps    | 20500        |
# | train/                |              |
# |    entropy_loss       | -42.4        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4099         |
# |    policy_loss        | 1.76         |
# |    reward             | 0.8993436    |
# |    reward_max         | 1.2372519    |
# |    reward_mean        | 0.41461906   |
# |    reward_min         | -0.059090257 |
# |    std                | 1.04         |
# |    value_loss         | 0.608        |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 134          |
# |    iterations         | 4200         |
# |    time_elapsed       | 155          |
# |    total_timesteps    | 21000        |
# | train/                |              |
# |    entropy_loss       | -42.3        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4199         |
# |    policy_loss        | -42.6        |
# |    reward             | 0.7917411    |
# |    reward_max         | 3.1171203    |
# |    reward_mean        | 1.3269722    |
# |    reward_min         | -0.005614896 |
# |    std                | 1.04         |
# |    value_loss         | 1.99         |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 4300          |
# |    time_elapsed       | 159           |
# |    total_timesteps    | 21500         |
# | train/                |               |
# |    entropy_loss       | -42.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 4299          |
# |    policy_loss        | 127           |
# |    reward             | 0.72807306    |
# |    reward_max         | 3.375302      |
# |    reward_mean        | 1.0148047     |
# |    reward_min         | -0.0030084576 |
# |    std                | 1.05          |
# |    value_loss         | 8.69          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 4400          |
# |    time_elapsed       | 163           |
# |    total_timesteps    | 22000         |
# | train/                |               |
# |    entropy_loss       | -42.4         |
# |    explained_variance | 0.0445        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 4399          |
# |    policy_loss        | 147           |
# |    reward             | -0.0014424177 |
# |    reward_max         | 1.8196145     |
# |    reward_mean        | 0.24358752    |
# |    reward_min         | -0.87357193   |
# |    std                | 1.05          |
# |    value_loss         | 12.9          |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 4500        |
# |    time_elapsed       | 166         |
# |    total_timesteps    | 22500       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4499        |
# |    policy_loss        | -87.1       |
# |    reward             | -1.7918338  |
# |    reward_max         | 1.4164649   |
# |    reward_mean        | 0.007863765 |
# |    reward_min         | -1.7918338  |
# |    std                | 1.05        |
# |    value_loss         | 8.08        |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 135            |
# |    iterations         | 4600           |
# |    time_elapsed       | 170            |
# |    total_timesteps    | 23000          |
# | train/                |                |
# |    entropy_loss       | -42.5          |
# |    explained_variance | 0.122          |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 4599           |
# |    policy_loss        | 1.96           |
# |    reward             | -0.00029377098 |
# |    reward_max         | 2.0442731      |
# |    reward_mean        | 0.12527713     |
# |    reward_min         | -1.7909274     |
# |    std                | 1.05           |
# |    value_loss         | 0.669          |
# ------------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4700       |
# |    time_elapsed       | 173        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | 50.3       |
# |    reward             | 1.8986106  |
# |    reward_max         | 3.6707501  |
# |    reward_mean        | 1.0651357  |
# |    reward_min         | -0.2428919 |
# |    std                | 1.05       |
# |    value_loss         | 1.43       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 4800        |
# |    time_elapsed       | 177         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | -63.2       |
# |    reward             | -0.89229536 |
# |    reward_max         | 13.433767   |
# |    reward_mean        | 1.7935569   |
# |    reward_min         | -4.0597925  |
# |    std                | 1.05        |
# |    value_loss         | 4.04        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4900       |
# |    time_elapsed       | 181        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -315       |
# |    reward             | 0.6669731  |
# |    reward_max         | 0.6669731  |
# |    reward_mean        | -3.1102068 |
# |    reward_min         | -8.7288    |
# |    std                | 1.05       |
# |    value_loss         | 64.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 5000       |
# |    time_elapsed       | 185        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -154       |
# |    reward             | 1.3560922  |
# |    reward_max         | 3.4546182  |
# |    reward_mean        | 0.3403445  |
# |    reward_min         | -1.9320935 |
# |    std                | 1.05       |
# |    value_loss         | 45         |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 5100          |
# |    time_elapsed       | 189           |
# |    total_timesteps    | 25500         |
# | train/                |               |
# |    entropy_loss       | -42.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5099          |
# |    policy_loss        | 575           |
# |    reward             | -0.0006414804 |
# |    reward_max         | 5.79224       |
# |    reward_mean        | 1.9762383     |
# |    reward_min         | -1.0469022    |
# |    std                | 1.05          |
# |    value_loss         | 191           |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 5200          |
# |    time_elapsed       | 192           |
# |    total_timesteps    | 26000         |
# | train/                |               |
# |    entropy_loss       | -42.5         |
# |    explained_variance | 0.139         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5199          |
# |    policy_loss        | 24.9          |
# |    reward             | -0.0003717326 |
# |    reward_max         | 0.7521819     |
# |    reward_mean        | 0.18087852    |
# |    reward_min         | -0.6228046    |
# |    std                | 1.05          |
# |    value_loss         | 0.366         |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 5300       |
# |    time_elapsed       | 196        |
# |    total_timesteps    | 26500      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5299       |
# |    policy_loss        | -127       |
# |    reward             | 0.18795027 |
# |    reward_max         | 0.18795027 |
# |    reward_mean        | -0.6548227 |
# |    reward_min         | -2.8758783 |
# |    std                | 1.06       |
# |    value_loss         | 9.18       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 5400        |
# |    time_elapsed       | 200         |
# |    total_timesteps    | 27000       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5399        |
# |    policy_loss        | 9.03        |
# |    reward             | 1.7075226   |
# |    reward_max         | 1.7075226   |
# |    reward_mean        | -0.42127833 |
# |    reward_min         | -2.0500228  |
# |    std                | 1.06        |
# |    value_loss         | 0.675       |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 134            |
# |    iterations         | 5500           |
# |    time_elapsed       | 204            |
# |    total_timesteps    | 27500          |
# | train/                |                |
# |    entropy_loss       | -42.8          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 5499           |
# |    policy_loss        | 58.2           |
# |    reward             | 0.5629664      |
# |    reward_max         | 1.3342023      |
# |    reward_mean        | 0.3873812      |
# |    reward_min         | -1.6075054e-06 |
# |    std                | 1.06           |
# |    value_loss         | 1.87           |
# ------------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 5600        |
# |    time_elapsed       | 208         |
# |    total_timesteps    | 28000       |
# | train/                |             |
# |    entropy_loss       | -42.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5599        |
# |    policy_loss        | 164         |
# |    reward             | 1.7531512   |
# |    reward_max         | 1.7531512   |
# |    reward_mean        | -0.67619306 |
# |    reward_min         | -3.8378892  |
# |    std                | 1.06        |
# |    value_loss         | 20.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 5700        |
# |    time_elapsed       | 211         |
# |    total_timesteps    | 28500       |
# | train/                |             |
# |    entropy_loss       | -42.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5699        |
# |    policy_loss        | -17.3       |
# |    reward             | 0.0         |
# |    reward_max         | 0.0         |
# |    reward_mean        | -0.54892987 |
# |    reward_min         | -1.6379452  |
# |    std                | 1.06        |
# |    value_loss         | 0.646       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 5800       |
# |    time_elapsed       | 215        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | 365        |
# |    reward             | 1.7865645  |
# |    reward_max         | 1.7865645  |
# |    reward_mean        | 0.16816546 |
# |    reward_min         | -1.8688364 |
# |    std                | 1.06       |
# |    value_loss         | 79.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 5900       |
# |    time_elapsed       | 219        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | 56.7       |
# |    reward             | -1.7639117 |
# |    reward_max         | 0.9829238  |
# |    reward_mean        | -0.305804  |
# |    reward_min         | -1.7639117 |
# |    std                | 1.06       |
# |    value_loss         | 2.65       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 6000        |
# |    time_elapsed       | 223         |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -42.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | 27.2        |
# |    reward             | -0.21158382 |
# |    reward_max         | 2.4595394   |
# |    reward_mean        | -0.06653493 |
# |    reward_min         | -1.5093105  |
# |    std                | 1.06        |
# |    value_loss         | 0.939       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 6100        |
# |    time_elapsed       | 227         |
# |    total_timesteps    | 30500       |
# | train/                |             |
# |    entropy_loss       | -42.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6099        |
# |    policy_loss        | 76.3        |
# |    reward             | 0.46679345  |
# |    reward_max         | 1.6976465   |
# |    reward_mean        | 0.23929168  |
# |    reward_min         | -0.96782315 |
# |    std                | 1.06        |
# |    value_loss         | 3.63        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 6200          |
# |    time_elapsed       | 230           |
# |    total_timesteps    | 31000         |
# | train/                |               |
# |    entropy_loss       | -43           |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 6199          |
# |    policy_loss        | 89.4          |
# |    reward             | 0.0           |
# |    reward_max         | 0.31171525    |
# |    reward_mean        | -0.0057176426 |
# |    reward_min         | -0.40778062   |
# |    std                | 1.07          |
# |    value_loss         | 5.8           |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 6300        |
# ...
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 7999          |
# |    policy_loss        | -85.1         |
# |    reward             | 1.7989451     |
# |    reward_max         | 1.9336501     |
# |    reward_mean        | 0.8972134     |
# |    reward_min         | -8.574518e-06 |
# |    std                | 1.1           |
# |    value_loss         | 4.59          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 8100          |
# |    time_elapsed       | 302           |
# |    total_timesteps    | 40500         |
# | train/                |               |
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8099          |
# |    policy_loss        | -8.86         |
# |    reward             | -0.0007000678 |
# |    reward_max         | 0.6215267     |
# |    reward_mean        | -0.009553902  |
# |    reward_min         | -0.853062     |
# |    std                | 1.1           |
# |    value_loss         | 0.0642        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 8200          |
# |    time_elapsed       | 305           |
# |    total_timesteps    | 41000         |
# | train/                |               |
# |    entropy_loss       | -43.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8199          |
# |    policy_loss        | -50.6         |
# |    reward             | 2.0206945     |
# |    reward_max         | 2.0206945     |
# |    reward_mean        | 0.88067174    |
# |    reward_min         | -0.0006191782 |
# |    std                | 1.1           |
# |    value_loss         | 1.4           |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 8300          |
# |    time_elapsed       | 309           |
# |    total_timesteps    | 41500         |
# | train/                |               |
# |    entropy_loss       | -44           |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8299          |
# |    policy_loss        | -1.43         |
# |    reward             | -0.0003152207 |
# |    reward_max         | 1.1515081     |
# |    reward_mean        | 0.26561365    |
# |    reward_min         | -0.6616195    |
# |    std                | 1.11          |
# |    value_loss         | 0.31          |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 134          |
# |    iterations         | 8400         |
# |    time_elapsed       | 312          |
# |    total_timesteps    | 42000        |
# | train/                |              |
# |    entropy_loss       | -44.1        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8399         |
# |    policy_loss        | -3.21        |
# |    reward             | -0.16659278  |
# |    reward_max         | 0.8115661    |
# |    reward_mean        | -0.098180726 |
# |    reward_min         | -1.1355244   |
# |    std                | 1.11         |
# |    value_loss         | 0.493        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 8500        |
# |    time_elapsed       | 316         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -44.2       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | -75.7       |
# |    reward             | 0.79912716  |
# |    reward_max         | 0.79912716  |
# |    reward_mean        | -0.13052224 |
# |    reward_min         | -1.5315083  |
# |    std                | 1.11        |
# |    value_loss         | 5.19        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 8600       |
# |    time_elapsed       | 319        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -44.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | -247       |
# |    reward             | -2.0690055 |
# |    reward_max         | 0.0        |
# |    reward_mean        | -0.9261446 |
# |    reward_min         | -2.0690055 |
# |    std                | 1.11       |
# |    value_loss         | 31.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 8700       |
# |    time_elapsed       | 323        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -44.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | -688       |
# |    reward             | 0.96776575 |
# |    reward_max         | 2.8689492  |
# |    reward_mean        | -0.4845573 |
# |    reward_min         | -6.2595015 |
# |    std                | 1.11       |
# |    value_loss         | 321        |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 134          |
# |    iterations         | 8800         |
# |    time_elapsed       | 327          |
# |    total_timesteps    | 44000        |
# | train/                |              |
# |    entropy_loss       | -44.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8799         |
# |    policy_loss        | -43.8        |
# |    reward             | 0.016672257  |
# |    reward_max         | 0.46304324   |
# |    reward_mean        | -0.060560696 |
# |    reward_min         | -0.77950716  |
# |    std                | 1.11         |
# |    value_loss         | 1.63         |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 8900          |
# |    time_elapsed       | 330           |
# |    total_timesteps    | 44500         |
# | train/                |               |
# |    entropy_loss       | -44.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8899          |
# |    policy_loss        | -61.2         |
# |    reward             | -0.0021324377 |
# |    reward_max         | 1.9103682     |
# |    reward_mean        | 0.3794459     |
# |    reward_min         | -0.22774175   |
# |    std                | 1.12          |
# |    value_loss         | 2.27          |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 9000        |
# |    time_elapsed       | 334         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -44.3       |
# |    explained_variance | -5.17       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | -14.6       |
# |    reward             | -1.4192318  |
# |    reward_max         | 0.38612616  |
# |    reward_mean        | -0.19406092 |
# |    reward_min         | -1.4192318  |
# |    std                | 1.12        |
# |    value_loss         | 0.493       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 9100        |
# |    time_elapsed       | 337         |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -44.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | -23.8       |
# |    reward             | -0.27276185 |
# |    reward_max         | -0.23716989 |
# |    reward_mean        | -0.5813995  |
# |    reward_min         | -1.5475522  |
# |    std                | 1.12        |
# |    value_loss         | 0.461       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 9200          |
# |    time_elapsed       | 341           |
# |    total_timesteps    | 46000         |
# | train/                |               |
# |    entropy_loss       | -44.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 9199          |
# |    policy_loss        | -1.72         |
# |    reward             | -0.98665786   |
# |    reward_max         | -0.0013245401 |
# |    reward_mean        | -0.3396673    |
# |    reward_min         | -0.98665786   |
# |    std                | 1.12          |
# |    value_loss         | 0.15          |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 9300        |
# |    time_elapsed       | 344         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -44.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | -10.4       |
# |    reward             | -1.5959716  |
# |    reward_max         | 2.4414024   |
# |    reward_mean        | 0.046582274 |
# |    reward_min         | -1.762239   |
# |    std                | 1.12        |
# |    value_loss         | 0.209       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 9400          |
# |    time_elapsed       | 348           |
# |    total_timesteps    | 47000         |
# | train/                |               |
# |    entropy_loss       | -44.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 9399          |
# |    policy_loss        | 28.9          |
# |    reward             | -0.0041551883 |
# |    reward_max         | 0.501218      |
# |    reward_mean        | -0.5004384    |
# |    reward_min         | -1.8254579    |
# |    std                | 1.13          |
# |    value_loss         | 0.41          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 134           |
# |    iterations         | 9500          |
# |    time_elapsed       | 352           |
# |    total_timesteps    | 47500         |
# | train/                |               |
# |    entropy_loss       | -44.6         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 9499          |
# |    policy_loss        | 22            |
# |    reward             | -0.0031471902 |
# |    reward_max         | 1.2426877     |
# |    reward_mean        | 0.308761      |
# |    reward_min         | -0.22457217   |
# |    std                | 1.13          |
# |    value_loss         | 0.276         |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 9600        |
# |    time_elapsed       | 355         |
# |    total_timesteps    | 48000       |
# | train/                |             |
# |    entropy_loss       | -44.6       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9599        |
# |    policy_loss        | 77.8        |
# |    reward             | 0.17669109  |
# |    reward_max         | 0.6067792   |
# |    reward_mean        | -0.24202463 |
# |    reward_min         | -1.9893017  |
# |    std                | 1.13        |
# |    value_loss         | 4.8         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 9700       |
# |    time_elapsed       | 359        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -44.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | -43.5      |
# |    reward             | 0.84816885 |
# |    reward_max         | 2.2389946  |
# |    reward_mean        | 0.18710525 |
# |    reward_min         | -3.603911  |
# |    std                | 1.13       |
# |    value_loss         | 5.11       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 9800        |
# |    time_elapsed       | 362         |
# |    total_timesteps    | 49000       |
# | train/                |             |
# |    entropy_loss       | -44.7       |
# |    explained_variance | 0.00579     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9799        |
# |    policy_loss        | 24.6        |
# |    reward             | -0.3949287  |
# |    reward_max         | 0.4134932   |
# |    reward_mean        | -0.29054043 |
# |    reward_min         | -1.4710867  |
# |    std                | 1.13        |
# |    value_loss         | 0.664       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 135          |
# |    iterations         | 9900         |
# |    time_elapsed       | 366          |
# |    total_timesteps    | 49500        |
# | train/                |              |
# |    entropy_loss       | -44.8        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9899         |
# |    policy_loss        | 7.8          |
# |    reward             | -1.3071351   |
# |    reward_max         | 0.0069693415 |
# |    reward_mean        | -1.5871444   |
# |    reward_min         | -4.5982437   |
# |    std                | 1.13         |
# |    value_loss         | 0.154        |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 135          |
# |    iterations         | 10000        |
# |    time_elapsed       | 370          |
# |    total_timesteps    | 50000        |
# | train/                |              |
# |    entropy_loss       | -44.8        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9999         |
# |    policy_loss        | -107         |
# |    reward             | -0.000991498 |
# |    reward_max         | 3.9098976    |
# |    reward_mean        | 0.13366269   |
# |    reward_min         | -5.005081    |
# |    std                | 1.14         |
# |    value_loss         | 6.48         |
# ----------------------------------------

# %% [markdown]
# ### Model 4: TD3

# %%
tmp_path = RESULTS_DIR + "/td3"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model_td3 = agent.get_model("td3")
model_td3.set_logger(new_logger)

if exists('./trained_models/trained_td3.model'):
    trained_td3 = model_td3.load('./trained_models/trained_td3.model')
else:
    if if_using_td3:
        # ВАЖНО: callback=None, чтобы FinRL-коллбэки не лезли в rollout_buffer
        model_td3.learn(
            total_timesteps=100_000,
            tb_log_name="td3",
            callback=None,
        )
        trained_td3 = model_td3 

        trained_td3.save('./trained_models/trained_td3.model')
# Out:
# Logging to results/td3
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 55       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 14604    |
# | train/             |          |
# |    actor_loss      | 55.9     |
# |    critic_loss     | 4.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14503    |
# ---------------------------------
# day: 3650, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2879685.05
# total_reward: 1879685.05
# total_cost: 1025.23
# total_trades: 69369
# Sharpe: 0.624
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 55       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 29208    |
# | train/             |          |
# |    actor_loss      | 31.8     |
# |    critic_loss     | 12       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29107    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 55       |
# |    time_elapsed    | 790      |
# |    total_timesteps | 43812    |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 3.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43711    |
# ---------------------------------
# day: 3650, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2879685.05
# total_reward: 1879685.05
# total_cost: 1025.23
# total_trades: 69369
# Sharpe: 0.624
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 55       |
# |    time_elapsed    | 1051     |
# |    total_timesteps | 58416    |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 3.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58315    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 55       |
# |    time_elapsed    | 1312     |
# |    total_timesteps | 73020    |
# | train/             |          |
# |    actor_loss      | 7.88     |
# |    critic_loss     | 3.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 72919    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 55       |
# |    time_elapsed    | 1586     |
# |    total_timesteps | 87624    |
# | train/             |          |
# |    actor_loss      | 4.37     |
# |    critic_loss     | 2.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87523    |
# ---------------------------------
# day: 3650, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2879685.05
# total_reward: 1879685.05
# total_cost: 1025.23
# total_trades: 69369
# Sharpe: 0.624
# =================================

# %% [markdown]
# ### Model 5: SAC

# %%
tmp_path = RESULTS_DIR + "/sac"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac", model_kwargs=SAC_PARAMS)
model_sac.set_logger(new_logger)

if exists('./trained_models/trained_sac.model'):
    trained_sac = model_sac.load('./trained_models/trained_sac.model')
else:
    if if_using_sac:
        # ВАЖНО: callback=None, чтобы FinRL-коллбэки не лезли в rollout_buffer
        model_sac.learn(
            total_timesteps=30_000,
            tb_log_name="sac",
            callback=None,
        )
        trained_sac = model_sac 

        trained_sac.save('./trained_models/trained_sac.model')
# Out:
# Logging to results/sac
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %% [markdown]
# ## Торговля
# В начальный момент времени (`TEST_START_DATE`) мы будем располагать начальным капиталом в 1,000,000$. Попробуем торговать с использование наших моделей на акциях списка Dow jones 30.

# %% [markdown]
# ### Торговля
#
# Модели DRL нужно периодически обновлять, чтобы использовать последние данные. В идеале, мы должны переобучать нашу модель ежегодно, ежеквартально или ежемесячно по мере убывания ее качества предсказания. Также нам нужно настраивать параметры.
# В этом примере мы используем только данные с 2009-01 по 2018-12 для настройки параметров модели один раз, поэтому здесь есть некоторое убывание качества модели со сременем.
#
# Множество гиперпараметров, таких как скорость обучения, общее количество образцов для обучения так же влияют на процесс обучения и обычно определяются путем тестирования различных вариантов. Пробуйте эти варианты самостоятельно для повышения качества моделей.

# %%
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade_data.head()
# Out:
#         date   tic       close        high         low        open  \
# 0 2019-01-01  AAPL   37.538826   37.759896   36.661683   36.818571
# 0 2019-01-01  AMGN  154.827866  155.876728  152.447763  155.328100
# 0 2019-01-01   AXP   86.900307   87.436164   85.165567   85.292727
# 0 2019-01-01    BA  314.645142  314.781193  304.830998  307.240817
# 0 2019-01-01   CAT  108.229256  109.513825  105.334695  106.216765
#
#         volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0  148158800.0  0.258891  0.227773  0.133360  ...     1.134347    0.854114
# 0    3009100.0  0.093973  0.072040  0.014094  ...     0.000000    0.000000
# 0    4175400.0  0.203479  0.160494  0.026811  ...     0.000000    0.000000
# 0    3292200.0  0.116496  0.102682  0.066409  ...     0.262465    0.092436
# 0    4783200.0  0.186871  0.107064  0.056932  ...     0.919490    0.266175
#
#    inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0     23.571867          7.620024          3.781658    0.690466
# 0      0.000000          0.351354          0.653355    0.869784
# 0      0.000000          0.231669          0.279424    0.887329
# 0      0.933164          5.468453          4.151637    0.998070
# 0      2.135008          2.339630          3.660183    0.803394
#
#    debt_to_equity          PE           PB  Div_yield
# 0        2.230663    5.602810     1.633781   0.019447
# 0        6.679531  499.444728    14.338642   0.001163
# 0        7.875371   48.011219     3.273722   0.004488
# 0      517.142241   83.019826  1418.196271   0.006531
# 0        4.086316   32.896430     4.008219   0.007946
#
# [5 rows x 22 columns]

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else [None, None]

df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else [None, None]

df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else [None, None]

df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else [None, None]

df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else [None, None]
# Out:
# hit end!
# hit end!
# hit end!
# hit end!
# hit end!

# %% [markdown]
# <a id='6'></a>
# # Часть 7: Проведение обратного тестирования торговой стратегии
#
# Обратное тестирование играет ключевую роль в оценке производительности торговой стратегии. Автоматизированный инструмент обратного тестирования предпочтительнее, поскольку он снижает вероятность человеческой ошибки.
#
# В `FinRL` обычно используется пакет `pyfolio` из `Quantopian` для обратного тестирования торговых стратегий. Он легок в использовании и состоит из различных отдельных графиков, которые предоставляют комплексное представление о производительности торговой стратегии.

# %% [markdown]
# <div class="alert alert-warning"><b>Ошибка обновления пакетов!</b>
#
# В данный момент пакет pyfolio отстает в обновлении от библиотек numpy и sklearn и при его использовании возникает ряд ошибок, связанных с несоотвествием типов данных.
#
# <b>Используйте его с осторожностью.</b></div>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

if if_using_ppo:
  print("\n ppo:")
  perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
  perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
  perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

if if_using_ddpg:
  print("\n ddpg:")
  perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
  perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
  perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

if if_using_a2c:
  print("\n a2c:")
  perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
  perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
  perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')

if if_using_td3:
  print("\n atd3:")
  perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
  perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
  perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

if if_using_sac:
  print("\n sac:")
  perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
  perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
  perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.039599
# Cumulative returns     0.119242
# Annual volatility      0.226397
# Sharpe ratio           0.285489
# Calmar ratio           0.114845
# Stability              0.072645
# Max drawdown          -0.344801
# Omega ratio            1.074217
# Sortino ratio          0.397030
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.935214
# Daily value at risk   -0.028267
# dtype: float64
#
#  ddpg:
# Annual return          0.095175
# Cumulative returns     0.301767
# Annual volatility      0.239442
# Sharpe ratio           0.501498
# Calmar ratio           0.251413
# Stability              0.105964
# Max drawdown          -0.378560
# Omega ratio            1.142782
# Sortino ratio          0.680862
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.033504
# Daily value at risk   -0.029690
# dtype: float64
#
#  a2c:
# Annual return          0.055966
# Cumulative returns     0.171124
# Annual volatility      0.216720
# Sharpe ratio           0.359901
# Calmar ratio           0.192391
# Stability              0.239203
# Max drawdown          -0.290894
# Omega ratio            1.093111
# Sortino ratio          0.513526
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.847709
# Daily value at risk   -0.026995
# dtype: float64
#
#  atd3:
# Annual return          0.129969
# Cumulative returns     0.425396
# Annual volatility      0.206989
# Sharpe ratio           0.695226
# Calmar ratio           0.405768
# Stability              0.446350
# Max drawdown          -0.320305
# Omega ratio            1.196229
# Sortino ratio          0.972505
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.947104
# Daily value at risk   -0.025507
# dtype: float64
#
#  sac:
# Annual return          0.150811
# Cumulative returns     0.503004
# Annual volatility      0.216102
# Sharpe ratio           0.759378
# Calmar ratio           0.475693
# Stability              0.689672
# Max drawdown          -0.317034
# Omega ratio            1.219119
# Sortino ratio          1.083452
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.954624
# Daily value at risk   -0.026575
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# Annual return          0.144674
# Cumulative returns     0.310981
# Annual volatility      0.274619
# Sharpe ratio           0.631418
# Calmar ratio           0.390102
# Stability              0.116677
# Max drawdown          -0.370862
# Omega ratio            1.149365
# Sortino ratio          0.870084
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.860710
# Daily value at risk   -0.033911
# dtype: float64

# %%
all_stats = pd.DataFrame(columns=['Baseline', 'SAC', 'PPO', 'DDPG', 'A2C', 'TD3'], index=['Annual return', 'Cumulative returns'])
all_stats['SAC']['Annual return'] = float(perf_stats_all_sac[0]['Annual return'])
all_stats['SAC']['Cumulative returns'] = float(perf_stats_all_sac[0]['Cumulative returns'])
all_stats['Baseline']['Annual return'] = float(stats['Annual return'])
all_stats['Baseline']['Cumulative returns'] = float(stats['Cumulative returns'])
all_stats['PPO']['Annual return'] = float(perf_stats_all_ppo[0]['Annual return'])
all_stats['PPO']['Cumulative returns'] = float(perf_stats_all_ppo[0]['Cumulative returns'])
all_stats['DDPG']['Annual return'] = float(perf_stats_all_ddpg[0]['Annual return'])
all_stats['DDPG']['Cumulative returns'] = float(perf_stats_all_ddpg[0]['Cumulative returns'])
all_stats['A2C']['Annual return'] = float(perf_stats_all_a2c[0]['Annual return'])
all_stats['A2C']['Cumulative returns'] = float(perf_stats_all_a2c[0]['Cumulative returns'])
all_stats['TD3']['Annual return'] = float(perf_stats_all_td3[0]['Annual return'])
all_stats['TD3']['Cumulative returns'] = float(perf_stats_all_td3[0]['Cumulative returns'])
all_stats = all_stats.apply(pd.to_numeric)
all_stats
# Out:
#                     Baseline       SAC       PPO      DDPG       A2C       TD3
# Annual return       0.144674  0.150811  0.039599  0.095175  0.055966  0.129969
# Cumulative returns  0.310981  0.503004  0.119242  0.301767  0.171124  0.425396

# %%
# Data for "Cumulative returns"
algorithms = list(all_stats.columns)
cumulative_returns = all_stats.loc[all_stats.index == 'Cumulative returns'].values[0]

# Create a bar chart with the modified colors
plt.figure(figsize=(10, 6))
plt.hlines(y=all_stats['Baseline']['Cumulative returns'], xmin=0, xmax=len(algorithms), colors='red', linestyles='dashed')
# Assigning a different color to 'Baseline' and a default color to others
colors = ['navy', 'tomato', 'skyblue', 'skyblue', 'skyblue', 'tomato']
plt.bar(algorithms, cumulative_returns, color=colors)
plt.xlabel('Algorithm')
plt.ylabel('Cumulative Returns')
plt.title('Cumulative Returns by Algorithm')
plt.xticks(rotation=45)
plt.savefig('Cumulative_returns.png')
plt.show()

# %% [markdown]
# ![file](Cumulative_returns.png)
